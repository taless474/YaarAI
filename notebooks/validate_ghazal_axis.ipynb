# %% [markdown]
# ### Validation of Ghazal-Level Semantic Axes (YaarAI)
#
# This notebook validates the **ghazal_axis** annotations generated for the YaarAI project.
#
# The goal is to ensure that:
# - each ghazal has a valid abstract semantic axis,
# - axes are concise noun phrases (not prose),
# - no verbal or directive language leaks into the annotations,
# - axes apply coherently across all bayts of a ghazal.
#
# This notebook is intended for **inspection and validation only**.
# No annotation or regeneration is performed here.

# %%
import json
import random
import re
from pathlib import Path
from collections import Counter, defaultdict

# %% [markdown]
# ### Load ghazal axis annotations
#
# We load the ghazal-level semantic axis annotations from disk and verify
# that the expected number of entries is present.

# %%
PATH = Path("../data/annotations/ghazal_axis_v1.jsonl")

rows = []
with PATH.open("r", encoding="utf-8") as f:
    for line in f:
        rows.append(json.loads(line))

len(rows) # there are 495 ghazals in Divan-e-Hafez
# Out:
# 495

# %% [markdown]
# ### Schema sanity check
#
# Each record must:
# - contain an integer `poem_id`
# - contain a non-empty string `ghazal_axis`

# %%
for r in rows:
    assert isinstance(r["poem_id"], int)
    assert isinstance(r["ghazal_axis"], str)
    assert r["ghazal_axis"].strip()

# %% [markdown]
# ### Axis length statistics
#
# We inspect the length (in words) of ghazal axes to ensure they remain
# short abstract noun phrases rather than explanatory prose.

# %%
lengths = [len(r["ghazal_axis"].split()) for r in rows]

min(lengths), max(lengths), round(sum(lengths) / len(lengths), 2)
# Out:
# (2, 10, 4.05)

# %% [markdown]
# ### Inspection of long axes
#
# Axes with unusually large word counts are inspected manually to ensure
# they are still semantically justified and not overly verbose.

# %%
long_axes = [r for r in rows if len(r["ghazal_axis"].split()) >= 8]
len(long_axes)
# Out:
# 7

# %%
for r in long_axes:
    print(len(r["ghazal_axis"].split()), "→", r["ghazal_axis"])
# Out:
# 8 → تغییر و دگرگونی در پیوندهای انسانی و معنوی
# 8 → جستجوی حقیقت و معرفت در پیوند با عشق
# 9 → پیوند مراتب وجودی و تمایز میان ظاهر و باطن
# 10 → پیوند رمز و نشانه‌های کیهانی با مفاهیم وفا و معرفت
# 8 → جستجوی کمال و معنا در پیوند با معشوق
# 8 → جستجوی معنای پایدار در پیوند انسانی و الهی
# 8 → جستجوی حقیقت در پیوند با معشوق و می

# %% [markdown]
# ### Verb-surface diagnostic (heuristic)
#
# As a diagnostic step, we scan for verb-like surface forms.
# This is not an error detector, but a sanity check against accidental
# prose leakage.

# %%
verb_like = re.compile(r"(می‌|می |کرد|شد|است|بود)")

bad = [r for r in rows if verb_like.search(r["ghazal_axis"])]
print(len(bad))
bad
# Out:
# 9
# [{'poem_id': 83,
#   'ghazal_axis': 'گذرا بودن وقایع و احوال',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 96,
#   'ghazal_axis': 'درخواست یاری در مواجهه با رنج\u200cهای بی\u200cپایان',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 168,
#   'ghazal_axis': 'ناکامی در تحقق آرمان',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 174,
#   'ghazal_axis': 'بازگشت و نو شدن',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 194,
#   'ghazal_axis': 'تعامل ناپایدار میان جذابیت و دست\u200cنیافتنی بودن',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 208,
#   'ghazal_axis': 'نبود ارزش\u200cهای بنیادین در زندگی',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 358,
#   'ghazal_axis': 'نبود امکان وصول حقیقت',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 405,
#   'ghazal_axis': 'تعامل انسان و قداست',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}},
#  {'poem_id': 442,
#   'ghazal_axis': 'فاصله و دست\u200cنیافتنی بودن',
#   'annotation_meta': {'model': 'gpt-4.1', 'prompt_version': 'v1.0'}}]

# %% [markdown]
# ### Axis frequency distribution
#
# We inspect the most frequent axes to understand the high-level
# semantic structure of the dataset and detect possible degeneracy.

# %%
axes = [r["ghazal_axis"] for r in rows]
Counter(axes).most_common(20)
# Out:
# [('جستجوی حقیقت پنهان', 12),
#  ('ناپایداری جهان', 4),
#  ('تمایز حقیقت و ظاهر', 4),
#  ('تقابل ظاهر و باطن', 4),
#  ('جستجوی وصال', 4),
#  ('جستجوی حقیقت مطلق', 3),
#  ('کشمکش درونی', 2),
#  ('پایداری پیوند معنوی', 2),
#  ('مرکزیت معشوق', 2),
#  ('پیوند ناپیدای دل و معشوق', 2),
#  ('جستجوی پیوند معنوی', 2),
#  ('پیوند ناپیدای عاشق و معشوق', 2),
#  ('جستجوی کمال', 2),
#  ('جدایی و پیوستگی', 2),
#  ('ناپایداری دستاوردها', 2),
#  ('پیچیدگی روابط انسانی', 2),
#  ('ترک تعلقات دنیوی', 2),
#  ('جدایی و بی\u200cاعتنایی', 2),
#  ('جستجوی حقیقت درونی', 2),
#  ('ناپایداری فرصت\u200cها', 2)]

# %% [markdown]
# ### Deep inspection of a frequent axis
#
# We select a frequent axis and inspect all bayts of its ghazals to ensure
# the axis applies coherently across the poem.

# %%
target_axis = "جستجوی حقیقت پنهان"

matching = [
    r for r in rows
    if r["ghazal_axis"] == target_axis
]

len(matching)
# Out:
# 12

# %% [markdown]
# ### Load raw ghazal text
#
# To contextualize axes, we load the original bayts for each ghazal.

# %%
RAW_PATH = Path("../data/raw/ghazals_with_insight.jsonl")

raw_by_poem = defaultdict(list)
with RAW_PATH.open("r", encoding="utf-8") as f:
    for line in f:
        r = json.loads(line)
        raw_by_poem[r["poem_id"]].append(r)

# %% [markdown]
# ### Inspect bayts under selected axis
#
# Each ghazal assigned to the selected axis is printed in full to confirm
# semantic alignment.

# %%
for r in matching:
    pid = r["poem_id"]
    print("=" * 60)
    print(f"poem_id = {pid}")
    print("AXIS:", r["ghazal_axis"])
    print("BAYTS:")
    for b in raw_by_poem[pid]:
        print("-", b["text"])
# Out:
# ============================================================
# poem_id = 7
# AXIS: جستجوی حقیقت پنهان
# BAYTS:
#
# - نمی‌بینم نشاط عیش در کس / نه درمان دلی نه درد دینی
# - درون‌ها تیره شد باشد که از غیب / چراغی برکند خلوت‌نشینی
# - گر انگشت سلیمانی نباشد / چه خاصیت دهد نقش نگینی؟
# - اگر چه رسم خوبان تندخویی‌ست / چه باشد گر بسازد با غمینی؟
# - ره میخانه بنما تا بپرسم / مآل خویش را از پیش‌بینی
# - نه حافظ را حضور درس خلوت / نه دانشمند را علم الیقینی

# %% [markdown]
# ### Inventory of all semantic axes
#
# This provides a full human-readable overview of the abstract semantic
# space covered by the dataset.

# %%
for axis in sorted(set(axes)):
    print(axis)
# Out:
# آرامش جویندگی در ناپایداری دنیا
# آرزوی بازگشت
# آرزوی دوام سلامت
# آرزوی وصال
# آرمان رهایی از قیود هستی
# آرمان وصال و هم‌نشینی
# آرمان‌گرایی در پیوند انسانی
# آزادی اندیشه و رهایی از قیود اجتماعی
# آمادگی و شایستگی برای تحول
# آگاهی از ارزش لحظه‌ها
# آیین همنشینی و آداب حضور
# آیین وفاداری و همدلی
# ابهام حقیقت و ظاهر
# ابهام در رفتار و جایگاه
# ابهام سرنوشت
# ادراک اسرار هستی
# ادراک حقیقت پنهان
# ارزش فرصت‌ها و پیوندهای انسانی
# ارزشمندی وصال و همنشینی
# ارزش‌های درونی و پیوندهای انسانی
# ارزش‌های متعالی زندگی
# ارزش‌های معنوی در برابر مظاهر دنیوی
# ارزش‌گذاری امور انسانی در برابر ناپایداری جهان
# ارزش‌گذاری معرفت
# ارزش‌گذاری و سنجش حقیقت
# ارزش‌یابی همراهی و گذر زمان
# اصالت و خلوص در سلوک انسانی
# اعتدال در داوری و رفتار
# امکان جستجوی جایگزین‌ها
# امکان رهایی و بازگشت
# امکان و تحول
# امکان و تصادف دست‌یابی
# امکانات مغفول
# امکان‌های نهفته در پیوندهای معنوی
# امکان‌گشایی و رفع انسداد
# امید بازگشت
# امید به بازگشت مطلوب
# امید به تحول احوال
# امید به دگرگونی و رهایی
# امید به دگرگونی وضعیت
# امید وصال
# امیدواری به تحول احوال
# امیدواری به دگرگونی و گشایش
# امیدواری در مواجهه با دشواری‌ها
# انتظار و تمنای وصال
# انتقال و دریافت معانی پنهان
# انتقال و واگذاری اختیار و سرنوشت
# بازتاب حقیقت در آیینه‌ی پندار
# بازنمایی خاطرات مشترک
# بازگشت و نو شدن
# بازگشت کامیابی و فرجام پیمان
# برتری انتخاب شخصی بر قواعد اجتماعی
# برتری عشق بر عقل و مقام اجتماعی
# برتری لطف بر تقصیر
# برتری معنا بر ظاهر
# برتری معنوی
# برتری معنوی درویشان
# برتری و بی‌نیازی
# برتری و تمایز معشوق
# برتری و شمول فرمانروایی
# برتری و کمال معشوق
# برتری و کمال معنوی
# برتری و یگانگی
# برتری و یگانگی معشوق
# بی‌نیازی در حضور کمال
# تأثیر حضور معشوق بر احوال شاعر
# تأثیر زیبایی بر سرنوشت
# تأثیر زیبایی و عشق بر سرنوشت انسان
# تأثیر ناپایداری روابط انسانی
# تأثیرپذیری جان از نیروی بیرونی
# تجدید حیات و وحدت
# تجربه جدایی و ناتوانی در وصال
# تجلی اثرگذاری جمال
# تجلی اراده و زیبایی مطلق
# تجلی تاثیر حضور یار
# تجلی خیال و یاد
# تجلی دگرگونی و تاثیر حضور
# تجلی دگرگونی و رهایی
# تجلی زیبایی و اثرگذاری صورت
# تجلی زیبایی و تاثیر آن بر جان‌ها
# تجلی زیبایی و تمنای وصال
# تجلی زیبایی و دگرگونی طبیعت
# تجلی فقدان و انتظار
# تجلی فیض و رهایی
# تجلی قدرت و تاثیر حضور
# تجلی معنا در تجربه‌های انسانی
# تجلی ناپایداری و دگرگونی
# تجلی و محدودیت ادراک
# تجلی وحدت در کثرت
# تجلی ویرانگری عشق
# تجلی کمال مطلوب
# تحول جایگاه درونی
# تحول سرنوشت
# تداخل سلوک و جدایی
# تداخل نمادهای دینی و عرفانی
# تداوم جستجوی وصال
# ترک تعلقات دنیوی
# ترک ریاضت صوری
# تسلط جلوه‌های معشوق بر قوای ادراک
# تضاد آرمان و واقعیت
# تضاد حضور و غیبت
# تضاد ظاهر و باطن
# تضاد مقام و حقیقت
# تضاد وفاداری و بی‌حاصلی
# تضاد پاکی و آلودگی
# تضادهای هستی‌شناختی
# تعادل میان دلبستگی و گذرایی
# تعادل میان ظاهر و باطن
# تعادل میان لذت و تقدیر
# تعارض آرمان و محدودیت
# تعارض ارزش‌های ظاهری و باطنی
# تعارض ظاهر و باطن
# تعارض عشق و زهد
# تعالی فضای معنوی و زیبایی‌شناختی
# تعالی معنوی از رهگذر عشق
# تعالی پیوند جاودان
# تعامل آرمانی و محدودیت‌های وصال
# تعامل ارزش‌ها و هنجارهای متعارض
# تعامل ارزش‌های ظاهری و باطنی
# تعامل انسان و تقدیر
# تعامل انسان و جهان ناپایدار
# تعامل انسان و قداست
# تعامل جلوه و طلب
# تعامل زیبایی و ناپایداری
# تعامل عاشق و معشوق
# تعامل عاشقانه انسان و جهان
# تعامل عرفان و تمنای وصال
# تعامل عرفان و شریعت
# تعامل عشق و رندی
# تعامل عشق و فریب
# تعامل قدرت و شفقت
# تعامل قضا و قدر و اختیار
# تعامل مفاهیم متضاد
# تعامل نابرابر عاشق و معشوق
# تعامل ناپایدار میان جذابیت و دست‌نیافتنی بودن
# تعلیق در انتظار بخشش و وفاداری
# تعلیق در تحقق آرزوها
# تعلیق و منع دسترسی
# تعلیمات معنوی و بی‌ثباتی دنیا
# تغییر حالات ادراک و آگاهی
# تغییر و دگرگونی در پیوندهای انسانی و معنوی
# تفاوت ظاهر و باطن
# تفاوت مراتب و مقامات
# تفاوت پندار و واقعیت در روابط انسانی
# تقابل اندیشه و تجربه
# تقابل تقدیر و اختیار
# تقابل جبر و اختیار
# تقابل ظاهر و باطن
# تقدیر و تحول
# تمایز حقیقت و ظاهر
# تمایز ظاهر و باطن
# تمایز میان عقل و عشق
# تناقض ظاهر و باطن
# تنوع جلوه‌های ارزش و کمال
# ثبات حقیقت پنهان
# جاذبه‌ی جمال و ناز معشوق
# جایگاه درونی انسان
# جایگاه معنوی معشوق
# جایگاه و اقتدار
# جایگاه و منزلت معنوی
# جدایی و بیگانگی
# جدایی و بی‌اعتنایی
# جدایی و بی‌وفایی
# جدایی و جستجوی حقیقت
# جدایی و جستجوی وصال
# جدایی و فقدان
# جدایی و پیوستگی
# جذب مستمر
# جریان گذرایی و دگرگونی هستی
# جستجوی امکان و کمال
# جستجوی بازگشت به اصل
# جستجوی بازگشت و پیوند
# جستجوی بی‌پایان
# جستجوی تحول و دگرگونی در وضعیت انسانی
# جستجوی حقیقت در ساحت تجربه و معرفت
# جستجوی حقیقت در عالم نمادین
# جستجوی حقیقت در مسیر عشق
# جستجوی حقیقت در مسیر پرآشوب زندگی
# جستجوی حقیقت در وادی عشق
# جستجوی حقیقت در ورای ظاهر
# جستجوی حقیقت در ورای ظواهر دنیا
# جستجوی حقیقت در پوشش ظاهرهای متضاد
# جستجوی حقیقت در پیوند با زیبایی
# جستجوی حقیقت در پیوند با معشوق
# جستجوی حقیقت در پیوند با معشوق و می
# جستجوی حقیقت در پیوند عاشق و معشوق
# جستجوی حقیقت درونی
# جستجوی حقیقت مطلق
# جستجوی حقیقت معنوی
# جستجوی حقیقت ناپیدا
# جستجوی حقیقت و اصالت
# جستجوی حقیقت و رهایی از تعلقات
# جستجوی حقیقت و مراتب کمال
# جستجوی حقیقت و معرفت
# جستجوی حقیقت و معرفت در پیوند با عشق
# جستجوی حقیقت و معنا
# جستجوی حقیقت پنهان
# جستجوی درمان معنوی
# جستجوی راه رهایی
# جستجوی راهنمایی و هدایت
# جستجوی رهایی از تعلقات دنیا
# جستجوی رهایی از دشواری‌های زندگی
# جستجوی رهایی از قیود روزمره
# جستجوی رهایی از قیود ظاهری
# جستجوی رهایی از وابستگی
# جستجوی رهایی در سایه زیبایی و تقدیر
# جستجوی رهایی در وابستگی
# جستجوی رهایی و تعالی
# جستجوی سرچشمه‌ی کمال
# جستجوی عنایت و واسطه‌جویی
# جستجوی معنا در ارزش‌های انسانی
# جستجوی معنا در تجربه‌های متضاد
# جستجوی معنا در رنج هستی
# جستجوی معنا در لذات زودگذر
# جستجوی معنا در مسیر بی‌پایان
# جستجوی معنا در ناتوانی و امید
# جستجوی معنا در ناپایداری دنیا
# جستجوی معنا در ورای ظواهر
# جستجوی معنا در گذر عمر
# جستجوی معنای جاودان
# جستجوی معنای وجودی
# جستجوی معنای پایدار در پیوند انسانی و الهی
# جستجوی معنوی
# جستجوی معنویت و بازگشت
# جستجوی معنویت و سرنوشت
# جستجوی ناتمام
# جستجوی هویت در پیوند با دگرگونی
# جستجوی هویت معشوق
# جستجوی وصال
# جستجوی وصال دست‌نیافتنی
# جستجوی وصال و بخشش
# جستجوی وصال و رهایی
# جستجوی وصال و ناتوانی انسانی
# جستجوی پیوستگی
# جستجوی پیوستگی مطلق
# جستجوی پیوند غایب
# جستجوی پیوند معنوی
# جستجوی پیوند ناپیدا
# جستجوی کمال
# جستجوی کمال در جذابیت و آرزو
# جستجوی کمال در جمال
# جستجوی کمال مطلق
# جستجوی کمال معنوی
# جستجوی کمال و معنا در پیوند با معشوق
# جلال و نظم سلطنتی
# حاکمیت تقدیر بر سرنوشت انسانی
# حضور مانع‌زدایی در وصال
# حفظ و مراقبت پیوندهای معنوی
# حکمت تقدیر و سرنوشت
# خودبسندگی وجودی
# درخواست یاری در مواجهه با رنج‌های بی‌پایان
# درک فرصت‌های گذرا
# دگرگونی ارزش‌ها
# دگرگونی حالات و مقامات
# دگرگونی درونی
# دگرگونی سرنوشت
# دگرگونی و گذر زمان
# رابطه وابستگی و تقدیر
# رابطه پنهان میان عاشق و معشوق
# رمز هستی و ناپایداری ادراک
# رمزگشایی حقیقت پنهان
# رهایی از تعلقات زمینی
# رهایی از خودپرستی
# رهایی از رنج تقدیر
# رهایی از قیدهای دنیوی
# رهایی از قیود خودپرستی و ظواهر
# رهایی از قیود ظاهری
# رهایی از قیود و جستجوی وصال
# زوال ارزش‌های اجتماعی
# ستایش منزلت معنوی
# ستایش موطن و آرمان‌شهر
# سخاوت معنوی
# سرنوشت ناپیدای جدایی و پیوند
# سلوک درونی
# سلوک عاشقانه
# سلوک معنوی
# سنجش ارزش‌های ظاهری و باطنی
# سیر تحول معرفت
# شکوه و فرهمندی پادشاهی
# ضرورت شکیبایی در مواجهه با دشواری‌ها
# طلب وصال
# طلب وصال و هم‌نشینی
# ظهور حقیقت درونی
# ظهور نظم و عدالت
# فاصله و انتظار
# فاصله و دست‌نیافتنی بودن
# فراق و ناکامی
# فراموشی و گذر از تعلقات
# فرصت بهره‌گیری از مواهب زمان
# فرصت‌طلبی و بهره‌جویی از لحظه‌ها
# فقدان امکان
# قناعت به داشته‌ها
# قناعت معنوی
# ماندگاری حقیقت پنهان
# مجلس آرمانی
# محدودیت و آرزومندی
# محدودیت وجودی
# محدودیت‌های ذاتی در پیوند انسانی
# محدودیت‌های ظاهری هستی
# محدودیت‌های هستی و گذرایی فرصت‌ها
# مراتب معرفت و حقیقت
# مرزهای ادراک
# مرزهای ادراک انسانی
# مرزهای حقیقت و ظاهر
# مرزهای معرفت و نادانی
# مرکزیت قدرت عادلانه
# مرکزیت قدرت و حکمت
# مرکزیت معشوق
# مرکزیت وجودی معشوق
# مواجهه با جدایی و تمنای وصال
# موانع و پیچیدگی‌های مسیر دستیابی
# موانع وصول
# نابرابری رابطه‌ها
# نابرابری ظاهری و حقیقت پنهان
# نابسامانی روابط انسانی
# ناتوانی انسان در برابر تقدیر
# ناتوانی انسان در برابر جاذبه کمال
# ناتوانی تأثیرگذاری اندرز بر سرشت
# ناتوانی در برابر سرنوشت
# ناتوانی در تحقق آرمان
# ناتوانی درک حقیقت
# ناتوانی عقل در برابر زیبایی
# ناپایداری احوال و جستجوی کمال
# ناپایداری احوال و دگرگونی سرنوشت
# ناپایداری امور جهان
# ناپایداری اوضاع زمانه
# ناپایداری جهان
# ناپایداری جهان و جستجوی بهره‌مندی
# ناپایداری جهان و رهایی از تعلقات
# ناپایداری دستاوردها
# ناپایداری زیبایی و جوانی
# ناپایداری فرصت‌ها
# ناپایداری لذات دنیا
# ناپایداری مظاهر دنیا
# ناپایداری مواهب دنیا
# ناپایداری وضعیت‌ها
# ناپایداری کامیابی‌ها
# ناکامی در تحقق آرمان
# نبود ارزش‌های بنیادین در زندگی
# نبود امکان وصول حقیقت
# نسبت انسان و تقدیر
# نسبت انسان و کمال مطلق
# نسبت انسان و کمال مطلوب
# نسبت دل و چشم
# نسبت میان جذابیت و بی‌اعتنایی
# نسبت میان جلال و فقر
# نسبت میان زیبایی و بی‌ثباتی
# نسبت میان زیبایی و رنج
# نسبت میان زیبایی و ناپایداری
# نسبت میان شریعت و عشق
# نسبت میان وابستگی و مرجعیت
# نسبت‌بخشی و تقسیم‌بندی مواهب هستی
# نسبت‌های نادرست و پیامدهای آن
# نسبیت ارزش‌ها و داوری‌ها
# نقد ارزش‌های انسانی و ناپایداری دنیا
# نقد ظاهرگرایی اجتماعی
# نوآوری و دگرگونی
# وابستگی وجودی
# واسطه‌گری پیام‌ها
# وفاداری مطلق به مرجع برتر
# پایان رنج و آغاز گشایش
# پایداری در رنج عشق
# پایداری در مسیر دگرگونی
# پایداری در مسیر طلب
# پایداری در مسیر عشق
# پایداری در ناپایداری‌ها
# پایداری در پیوند معنوی
# پایداری در پیگیری مطلوب برتر
# پایداری سرنوشت و رمزآلودگی حقیقت
# پایداری نعمت و پیوستگی سعادت
# پایداری پیوند ذهنی
# پایداری پیوند معنوی
# پایداری پیوند ناپیدا
# پرسش از حقیقت و ماهیت امور
# پرسشگری پیامدها
# پناه‌جویی در برابر ناپایداری جهان
# پویایی وابستگی و بی‌اعتنایی
# پویش درونی برای رهایی و دگرگونی
# پویش ناتمام
# پیامدهای جدایی و پذیرش شرایط
# پیام‌رسانی معنوی
# پیوند آرمان و تقدیر
# پیوند اضداد
# پیوند انتظار و جدایی
# پیوند بندگی و طلب
# پیوند تجربه‌های فردی با مفاهیم گذرا
# پیوند تمنای وصال و امید
# پیوند تمنای وصال و فراق
# پیوند خطا و امید
# پیوند راز و لذت
# پیوند رمز و نشانه‌های کیهانی با مفاهیم وفا و معرفت
# پیوند رنج و امید
# پیوند رنج و شور
# پیوند زیبایی و ناپایداری
# پیوند ظاهر و باطن
# پیوند عاشق و معشوق
# پیوند عناصر ظاهری و معنوی معشوق
# پیوند عنایت و شکرگزاری
# پیوند مراتب وجودی
# پیوند مراتب وجودی و تمایز میان ظاهر و باطن
# پیوند معرفت و عشق
# پیوند نادیدنی میان ظاهر و باطن
# پیوند ناپایدار میان آرزو و فراق
# پیوند ناپایدار میان دلبستگی و جدایی
# پیوند ناپایدار میان دلبستگی و دگرگونی
# پیوند ناپیدای دل و معشوق
# پیوند ناپیدای عاشق و معشوق
# پیوند هستی و عشق
# پیوند هستی و معشوق
# پیوند و جدایی
# پیوند وابستگی و تعلق
# پیوند وجودی
# پیوند پنهان میان ظاهر و باطن
# پیچیدگی حقیقت هستی
# پیچیدگی راه و منزلگاه
# پیچیدگی روابط انسانی
# پیچیدگی روابط انسانی و ناپیدایی حقیقت
# پیچیدگی سرنوشت
# پیچیدگی مناسبات انسانی
# پیچیدگی مناسبات عاشقانه
# پیچیدگی مناسبات عشق و زیبایی
# پی‌جویی حقیقت در پیوند و جدایی
# چرخش سرنوشت و جستجوی رهایی
# چرخه‌ی زمان و دگرگونی فرصت‌ها
# چرخه‌ی زوال و امید
# کثرت در وحدت
# کثرت و تنوع در جستجوی حقیقت
# کشمکش ارزش‌ها
# کشمکش درونی
# کمال مطلق زیبایی
# کمال مطلوب
# کمال‌بخشی حضور
# گذر از محدودیت‌های عقلانی
# گذر زمان و ناپایداری هستی
# گذر فرصت‌ها و بهره‌گیری از لحظه‌ها
# گذرا بودن وقایع و احوال
# گذران زمان و بهره‌گیری از فرصت‌ها
# گذران زمان و ناپایداری دنیا
# گذران فرصت و بهره‌گیری از مواهب زمان
# گذران فرصت‌ها
# گذران فرصت‌های زودگذر
# گذران ناپایدار زیبایی و تمنای وصال
# گذران و ناپایداری دنیا
# گذرایی فرصت‌ها
# گردش احوال جهان
# گردش دگرگونی‌ها
# یادآوری پیوندهای انسانی
# یادآوری پیوندهای گذشته
# یادمان جمعی ارزش‌ها و پیوندها

# %% [markdown]
# ### Random global sanity check
#
# A small random sample of ghazals is inspected to ensure no anomalies
# remain after all validation steps.

# %%
random.seed(42)

for r in random.sample(rows, 3):
    print("AXIS:", r["ghazal_axis"])
    print("BAYTS:")
    for b in raw_by_poem[r["poem_id"]]:
        print("-", b["text"])
    print("-" * 40)
# Out:
# AXIS: جستجوی کمال معنوی
# BAYTS:
# - من که باشم که بر آن خاطر عاطر گذرم؟ / لطف‌ها می‌کنی ای خاک درت، تاج سرم
# - دلبرا بنده نوازیت که آموخت؟ بگو / که من این ظن، به رقیبان تو هرگز نبرم
# - همتم بدرقه‌ی راه کن ای طایر قدس / که دراز است ره مقصد و من نوسفرم
# - ای نسیم سحری بندگی من برسان / که فراموش مکن وقت دعای سحرم
# - خرم آن روز کز این مرحله بربندم بار / و از سر کوی تو پرسند رفیقان خبرم
# - حافظا شاید اگر در طلب گوهر وصل / دیده دریا کنم از اشک و در او غوطه خورم
# - پایه‌ی نظم بلند است و جهان گیر بگو / تا کند پادشه بحر دهان پر گهرم
# ----------------------------------------
# AXIS: تجلی اراده و زیبایی مطلق
# BAYTS:
# - سر ارادت ما و آستان حضرت دوست / که هر چه بر سر ما می‌رود ارادت اوست
# - نظیر دوست ندیدم، اگر چه از مه و مهر / نهادم آینه‌ها در مقابل رخ دوست
# - صبا ز حال دل تنگ ما چه شرح دهد؟ / که چون شکنج ورق‌های غنچه تو بر توست
# - نه من سبوکش این دیر رندسوزم و بس / بسا سرا که در این کارخانه سنگ و سبوست
# - مگر تو شانه زدی زلف عنبرافشان را؟ / که باد غالیه‌سا گشت و خاک عنبربوست
# - نثار روی تو هر برگ گل که در چمن است / فدای قد تو هر سروبن که بر لب جوست
# - زبان ناطقه در وصف شوق نالان است / چه جای کلک بریده‌زبان بیهده‌گوست؟
# - رخ تو در دلم آمد مراد خواهم یافت / چرا که حال نکو در قفای فال نکوست
# - نه این زمان دل حافظ در آتش هوس است / که داغدار ازل همچو لاله‌ی خودروست
# ----------------------------------------
# AXIS: فرصت بهره‌گیری از مواهب زمان
# BAYTS:
# - می‌دمد صبح و کله بست سحاب / الصبوح الصبوح یا اصحاب
# - می‌چکد ژاله بر رخ لاله / المدام المدام یا احباب
# - می‌وزد از چمن نسیم بهشت / هان، بنوشید دم به دم می ناب
# - تخت زمرد زده است گل به چمن / راح چون لعل آتشین دریاب
# - در میخانه بسته‌اند دگر / افتتح یا مفتح الابواب
# - لب و دندانت را حقوق نمک / هست بر جان و سینه‌های کباب
# - این چنین موسمی عجب باشد / که ببندند میکده به شتاب
# - بر رخ ساقی پری پیکر / همچو حافظ بنوش باده‌ی ناب
# ----------------------------------------
