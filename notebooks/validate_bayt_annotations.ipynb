# %% [markdown]
# ### Validation of Bayt-Level Semantic Annotations (YaarAI)
#
# This notebook validates **bayt-level semantic annotations** used in YaarAI,
# including:
#
# - `bayt_hint`: a short noun phrase describing what happens in the bayt
# - `affect`: up to two affect labels drawn from a fixed vocabulary
#
# The goals of this notebook are to:
# - verify schema correctness,
# - inspect annotation distributions,
# - validate repairs and normalizations,
# - perform random qualitative checks with full bayt context.
#
# This notebook performs no regeneration.

# %%
import json
import random
import re
from pathlib import Path
from collections import Counter, defaultdict

# %% [markdown]
# ### Load raw bayt text
#
# Raw bayt text is loaded once and reused throughout the notebook
# to provide full poetic context during inspection.

# %%
RAW_PATH = Path("../data/raw/ghazals_with_insight.jsonl")

raw_by_key = {}
raw_by_poem = defaultdict(list)

with RAW_PATH.open("r", encoding="utf-8") as f:
    for line in f:
        r = json.loads(line)
        key = (r["poem_id"], r["bayt_id"])
        raw_by_key[key] = r["text"]
        raw_by_poem[r["poem_id"]].append(r)

len(raw_by_key)
# Out:
# 4192

# %% [markdown]
# ### Why multiple bayt annotation versions exist
#
# Bayt-level semantic annotations in YaarAI were refined through a
# **multi-stage, quality-driven process**.
#
# Rather than overwriting results, each refinement produced a new version
# to ensure transparency, reproducibility, and auditability.
#
# The annotation versions are:
#
# - **v1 — Initial extraction**
#   First-pass GPT-4.1 extraction of:
#   - `bayt_hint`: a short noun phrase describing what happens in the bayt
#   - `affect`: up to two affect labels from a fixed vocabulary
#
# - **v1.1 — Conciseness & drift repair**
#   An automated repair pass applied to bayt hints that exceeded a length
#   threshold or showed interpretive / explanatory drift.
#   This step improved abstraction while preserving meaning.
#
# - **v1.2 — Directive normalization (explicit)**
#   Deterministic, rule-based removal of explicit directive framing such as:
#   - «دعوت به …»
#   - «توصیه به …»
#   - «تشویق به …»
#
# - **v1.3 — Directive normalization (residual)**
#   Final normalization pass removing residual *soft directive* prefixes
#   left behind after earlier repairs, including:
#   - «توجه به …»
#   - «بهره‌گیری از …»
#
#   This step completes the transition to **fully descriptive,
#   non-directive bayt hints**, without regeneration or semantic reinterpretation.
#
# This notebook validates the **final canonical version (v1.3)**.
# Earlier versions are retained for reference and provenance.

# %%
ANNOTATION_PATH = Path("../data/annotations/bayt_annotations_v1_3.jsonl")

rows = []
with ANNOTATION_PATH.open("r", encoding="utf-8") as f:
    for line in f:
        rows.append(json.loads(line))

len(rows)
# Out:
# 4192

# %% [markdown]
# ### What is validated in this notebook
#
# This notebook validates the **final canonical bayt annotation layer (v1.3)**.
#
# The following aspects are checked:
#
# - schema correctness (`poem_id`, `bayt_id`, `bayt_hint`, `affect`)
# - conciseness of `bayt_hint` (noun phrase, not prose)
# - absence of directive or verbal framing
# - reasonable distribution of affect labels
# - semantic alignment between bayt text, hint, and affect
#
# All checks are **diagnostic and qualitative**.
# No further annotation, regeneration, or normalization is performed here.

# %%
for r in rows:
    assert isinstance(r["poem_id"], int)
    assert isinstance(r["bayt_id"], int)
    assert isinstance(r["bayt_hint"], str)
    assert r["bayt_hint"].strip()
    assert isinstance(r["affect"], list)
    assert len(r["affect"]) <= 2

# %% [markdown]
# ### Bayt hint length statistics
#
# Bayt hints should remain short noun phrases, not explanatory prose.

# %%
lengths = [len(r["bayt_hint"].split()) for r in rows]

min(lengths), max(lengths), round(sum(lengths) / len(lengths), 2)
# Out:
# (1, 9, 5.2)

# %% [markdown]
# ### Inspection of long bayt hints
#
# Bayt hints exceeding a length threshold are inspected manually
# to detect interpretive drift.

# %%
long_hints = [r for r in rows if len(r["bayt_hint"].split()) >= 8]
len(long_hints)
# Out:
# 246

# %%
for r in long_hints:
    key = (r["poem_id"], r["bayt_id"])
    print(f"poem_id={r['poem_id']} bayt_id={r['bayt_id']}")
    print("BAYT:", raw_by_key.get(key))
    print("HINT:", r["bayt_hint"])
    print("-" * 80)
# Out:
# poem_id=3 bayt_id=2
# BAYT: بده ساقی می باقی که در جنت نخواهی یافت / کنار آب رکناباد و گل‌گشت مصلا را
# HINT: درخواست می باقی در کنار آب و گل‌گشت
# --------------------------------------------------------------------------------
# poem_id=5 bayt_id=6
# BAYT: آسایش دو گیتی تفسیر این دو حرف است / با دوستان مروت با دشمنان مدارا
# HINT: پند اخلاقی درباره رفتار با دوستان و دشمنان
# --------------------------------------------------------------------------------
# poem_id=5 bayt_id=10
# BAYT: سرکش مشو که چون شمع از غیرتت بسوزد / دلبر که در کف او موم است سنگ خارا
# HINT: هشدار به سرکشی عاشق در برابر دلبر قدرتمند
# --------------------------------------------------------------------------------
# poem_id=5 bayt_id=12
# BAYT: خوبان پارسی‌گو بخشندگان عمرند / ساقی بده بشارت رندان پارسا را
# HINT: بخشش عمر از سوی خوبان به رندان پارسا
# --------------------------------------------------------------------------------
# poem_id=6 bayt_id=3
# BAYT: مژه‌ی سیاهت ار کرد به خون ما اشارت / ز فریب او بیندیش و غلط مکن، نگارا
# HINT: اشارت مژه به خونریزی و هشدار از فریب
# --------------------------------------------------------------------------------
# poem_id=10 bayt_id=5
# BAYT: روی خوبت آیتی از لطف بر ما کشف کرد / زان زمان جز لطف و خوبی نیست در تفسیر ما
# HINT: کشف زیبایی و لطف از طریق مشاهده معشوق
# --------------------------------------------------------------------------------
# poem_id=12 bayt_id=3
# BAYT: کس به دور نرگست طرفی نبست از عافیت / به که نفروشند مستوری به مستان شما
# HINT: مقایسه مستوری و مستی در برابر چشم یار
# --------------------------------------------------------------------------------
# poem_id=13 bayt_id=6
# BAYT: لب و دندانت را حقوق نمک / هست بر جان و سینه‌های کباب
# HINT: حق‌گزاری جان سوخته بر لب و دندان معشوق
# --------------------------------------------------------------------------------
# poem_id=14 bayt_id=1
# BAYT: گفتم ای سلطان خوبان رحم کن بر این غریب / گفت در دنبال دل، ره گم کند مسکین غریب
# HINT: گفت‌وگوی عاشق و معشوق درباره غریبی و گم‌گشتگی
# --------------------------------------------------------------------------------
# poem_id=17 bayt_id=7
# BAYT: ماجرا کم کن و بازآ که مرا مردم چشم / خرقه از سر به درآورد و به شکرانه بسوخت
# HINT: درخواست بازگشت معشوق و اشاره به تاثیر دیدار
# --------------------------------------------------------------------------------
# poem_id=18 bayt_id=7
# BAYT: حافظ از دست مده دولت این کشتی نوح / ور نه طوفان حوادث ببرد بنیادت
# HINT: هشدار به حفظ نعمت و دوری از خطر
# --------------------------------------------------------------------------------
# poem_id=19 bayt_id=6
# BAYT: باز پرسید ز گیسوی شکن در شکنش / کاین دل غم‌زده سرگشته گرفتار کجاست؟
# HINT: پرسش از گیسوی معشوق درباره جای دل عاشق
# --------------------------------------------------------------------------------
# poem_id=21 bayt_id=4
# BAYT: در چمن، باد بهاری ز کنار گل و سرو / به هواداری آن عارض و قامت برخاست
# HINT: وزش نسیم بهاری در کنار گل و سرو
# --------------------------------------------------------------------------------
# poem_id=26 bayt_id=2
# BAYT: نرگسش عربده‌جوی و لبش افسوس‌کنان / نیم شب، دوش به بالین من آمد، بنشست
# HINT: حضور معشوق با نگاه تند و لب اندوهگین
# --------------------------------------------------------------------------------
# poem_id=29 bayt_id=1
# BAYT: ما را ز خیال تو چه پروای شراب است؟ / خم گو سر خود گیر، که خمخانه خراب است
# HINT: بی‌نیازی از شراب به سبب حضور خیال معشوق
# --------------------------------------------------------------------------------
# poem_id=30 bayt_id=2
# BAYT: تا عاشقان به بوی نسیمش دهند جان / بگشود نافه‌ای و در آرزو ببست
# HINT: بوی خوش نسیم و بسته شدن در آرزو
# --------------------------------------------------------------------------------
# poem_id=33 bayt_id=3
# BAYT: ای پادشاه حسن خدا را بسوختیم / آخر سوال کن که گدا را چه حاجت است
# HINT: خطاب به معشوق و بیان حال عاشق سوخته‌دل
# --------------------------------------------------------------------------------
# poem_id=36 bayt_id=3
# BAYT: در خم زلف تو آن خال سیه دانی چیست؟ / نقطه‌ی دوده که در حلقه جیم افتادست
# HINT: تشبیه خال معشوق به نقطه جیم در زلف
# --------------------------------------------------------------------------------
# poem_id=40 bayt_id=5
# BAYT: شرح شکن زلف خم اندر خم جانان / کوته نتوان کرد که این قصه، دراز است
# HINT: توصیف پیچیدگی و طولانی بودن داستان زلف معشوق
# --------------------------------------------------------------------------------
# poem_id=40 bayt_id=6
# BAYT: بار دل مجنون و خم طره‌ی لیلی / رخساره‌ی محمود و کف پای ایاز است
# HINT: تصویرسازی از بار دل عاشق و زیبایی معشوق
# --------------------------------------------------------------------------------
# poem_id=41 bayt_id=6
# BAYT: سپهر بر شده پرویزنی‌ست خون افشان / که ریزه‌اش سر کسری و تاج پرویز است
# HINT: تصویرگری آسمان خون‌افشان و فرو افتادن شکوه پادشاهی
# --------------------------------------------------------------------------------
# poem_id=42 bayt_id=5
# BAYT: ای صبا امشبم مدد فرمای / که سحرگه شکفتنم، هوس است
# HINT: درخواست یاری از باد صبا برای شکفتن صبحگاهی
# --------------------------------------------------------------------------------
# poem_id=42 bayt_id=7
# BAYT: همچو حافظ به رغم مدعیان / شعر رندانه گفتنم، هوس است
# HINT: اصرار بر سرودن شعر رندانه در برابر مخالفت
# --------------------------------------------------------------------------------
# poem_id=44 bayt_id=2
# BAYT: بخواه دفتر اشعار و راه صحرا گیر / چه وقت مدرسه و بحث کشف کشاف است؟
# HINT: ترک درس و گرایش به شعر و طبیعت
# --------------------------------------------------------------------------------
# poem_id=45 bayt_id=5
# BAYT: بگیر طره‌ی مه‌چهره‌ای و قصه مخوان / که سعد و نحس ز تاثیر زهره و زحل است
# HINT: اشاره به زیبایی چهره و بی‌اعتنایی به سرنوشت
# --------------------------------------------------------------------------------
# poem_id=46 bayt_id=6
# BAYT: از چاشنی قند مگو هیچ و ز شکر / زان رو که مرا از لب شیرین تو، کام است
# HINT: مقایسه شیرینی لب معشوق با قند و شکر
# --------------------------------------------------------------------------------
# poem_id=48 bayt_id=1
# BAYT: صوفی از پرتو می راز نهانی دانست / گوهر هر کس از این لعل، توانی دانست
# HINT: کشف حقیقت با می و شناخت گوهر انسان
# --------------------------------------------------------------------------------
# poem_id=48 bayt_id=9
# BAYT: حافظ این گوهر منظوم که از طبع انگیخت / ز اثر تربیت آصف ثانی دانست
# HINT: نسبت دادن سرایش شعر به تربیت آصف ثانی
# --------------------------------------------------------------------------------
# poem_id=49 bayt_id=4
# BAYT: آن چه زر می‌شود از پرتو آن قلب سیاه / کیمیاییست که در صحبت درویشان است
# HINT: تبدیل قلب ناپاک به ارزشمندی در مصاحبت درویشان
# --------------------------------------------------------------------------------
# poem_id=51 bayt_id=4
# BAYT: بنده‌ی طالع خویشم که در این قحط وفا / عشق آن لولی سرمست، خریدار من است
# HINT: سپاسگزاری از بخت نیک، دلبستگی به معشوق بی‌وفا
# --------------------------------------------------------------------------------
# poem_id=52 bayt_id=1
# BAYT: روزگاری‌ست که سودای بتان، دین من است / غم این کار، نشاط دل غمگین من است
# HINT: دلبستگی به معشوق و لذت از رنج عشق
# --------------------------------------------------------------------------------
# poem_id=52 bayt_id=3
# BAYT: یار من باش که زیب فلک و زینت دهر / از مه روی تو و اشک چو پروین من است
# HINT: درخواست یاری معشوق و توصیف زیبایی و اشک
# --------------------------------------------------------------------------------
# poem_id=56 bayt_id=1
# BAYT: دل سراپرده‌ی محبت اوست / دیده آیینه‌دار طلعت اوست
# HINT: مرکزیت دل و دیده در ارتباط با معشوق
# --------------------------------------------------------------------------------
# poem_id=58 bayt_id=3
# BAYT: صبا ز حال دل تنگ ما چه شرح دهد؟ / که چون شکنج ورق‌های غنچه تو بر توست
# HINT: ابهام حال دل تنگ، بسته بودن راز دل
# --------------------------------------------------------------------------------
# poem_id=62 bayt_id=2
# BAYT: واله و شیداست دایم همچو بلبل در قفس / طوطی طبعم ز عشق شکر و بادام دوست
# HINT: دل شیدا در قفس، طبع عاشق و شیرین
# --------------------------------------------------------------------------------
# poem_id=65 bayt_id=3
# BAYT: پیوند عمر بسته به مویی‌ست هوش دار / غمخوار خویش باش، غم روزگار چیست؟
# HINT: ناپایداری عمر و توصیه به مراقبت از خود
# --------------------------------------------------------------------------------
# poem_id=65 bayt_id=6
# BAYT: راز درون پرده چه داند فلک، خموش / ای مدعی نزاع تو با پرده‌دار چیست؟
# HINT: پرسش از نادانی فلک نسبت به راز نهان
# --------------------------------------------------------------------------------
# poem_id=70 bayt_id=2
# BAYT: اشکم احرام طواف حرمت می‌بندد / گرچه از خون دل ریش دمی طاهر نیست
# HINT: آمادگی اشک برای طواف حرمت با دل ناپاک
# --------------------------------------------------------------------------------
# poem_id=73 bayt_id=5
# BAYT: تا دم از شام سر زلف تو هر جا نزنند / با صبا گفت و شنیدم سحری نیست که نیست
# HINT: گفت‌وگوی سحرگاهی با باد صبا درباره زلف یار
# --------------------------------------------------------------------------------
# poem_id=73 bayt_id=9
# BAYT: شیر در بادیه‌ی عشق تو روباه شود / آه از این راه که در وی خطری نیست که نیست
# HINT: تبدیل شجاعت به ترس در مسیر پرخطر عشق
# --------------------------------------------------------------------------------
# poem_id=74 bayt_id=2
# BAYT: از دل و جان شرف صحبت جانان غرض است / غرض این است، وگرنه دل و جان این همه نیست
# HINT: ارزش‌یابی دل و جان در پیوند با معشوق
# --------------------------------------------------------------------------------
# poem_id=76 bayt_id=3
# BAYT: چرا ز کوی خرابات روی برتابم؟ / کز این بهم به جهان، هیچ رسم و راهی نیست
# HINT: پرسش از ترک خرابات و بیان بی‌قاعدگی جهان
# --------------------------------------------------------------------------------
# poem_id=80 bayt_id=3
# BAYT: همه‌کس، طالب یارند؛ چه هشیار و چه مست / همه‌جا، خانه‌ی عشق است؛ چه مسجد چه کنشت
# HINT: طلب معشوق همگانی، حضور عشق در همه مکان‌ها
# --------------------------------------------------------------------------------
# poem_id=80 bayt_id=4
# BAYT: سر تسلیم من و خشت در میکده‌ها / مدعی گر نکند فهم سخن، گو سر و خشت
# HINT: تسلیم در میکده و بی‌اعتنایی به داوری مدعی
# --------------------------------------------------------------------------------
# poem_id=81 bayt_id=4
# BAYT: تا ابد، بوی محبت به مشامش نرسد / هر که خاک در میخانه به رخساره نرفت
# HINT: محرومیت از محبت به سبب دوری از میخانه
# --------------------------------------------------------------------------------
# poem_id=83 bayt_id=2
# BAYT: برق عشق ار خرمن پشمینه پوشی سوخت سوخت / جور شاه کامران گر بر گدایی رفت رفت
# HINT: سوختن خرقه درویشی و بی‌اعتنایی به جفای پادشاه
# --------------------------------------------------------------------------------
# poem_id=86 bayt_id=3
# BAYT: آن عشوه داد عشق که مفتی ز ره برفت / وان لطف کرد دوست که دشمن حذر گرفت
# HINT: تغییر احوال بر اثر رفتار عشق و دوست
# --------------------------------------------------------------------------------
# poem_id=87 bayt_id=6
# BAYT: آن روز شوق ساغر می، خرمنم بسوخت / که آتش ز عکس عارض ساقی در آن گرفت
# HINT: سوختن خرمن از شوق ساغر و عکس عارض ساقی
# --------------------------------------------------------------------------------
# poem_id=87 bayt_id=7
# BAYT: خواهم شدن به کوی مغان آستین‌فشان / زین فتنه‌ها که دامن آخرزمان گرفت
# HINT: حرکت به سوی میخانه با رهایی از آشوب
# --------------------------------------------------------------------------------
# poem_id=88 bayt_id=6
# BAYT: غم کهن به می سال‌خورده دفع کنید / که تخم خوش‌دلی این است؛ پیر دهقان گفت
# HINT: پند پیرانه برای رفع غم با می کهنه
# --------------------------------------------------------------------------------
# poem_id=88 bayt_id=8
# BAYT: به مهلتی که سپهرت دهد ز راه مرو / تو را که گفت که این زال ترک دستان گفت؟
# HINT: پند به پرهیز از غرور در برابر تقدیر
# --------------------------------------------------------------------------------
# poem_id=90 bayt_id=5
# BAYT: تا لشکر غمت نکند ملک دل خراب / جان عزیز خود به نوا می‌فرستمت
# HINT: پیشکش جان به معشوق پیش از هجوم غم
# --------------------------------------------------------------------------------
# poem_id=93 bayt_id=7
# BAYT: روان تشنه‌ی ما را به جرعه‌ای دریاب / چو می‌دهند زلال خضر ز جام جمت
# HINT: درخواست سیراب شدن دل تشنه با جرعه‌ای زلال
# --------------------------------------------------------------------------------
# poem_id=94 bayt_id=5
# BAYT: چشمت به غمزه ما را، خون خورد و می‌پسندی / جانا روا نباشد، خون‌ریز را حمایت
# HINT: سرزنش معشوق به سبب حمایت از چشم خونریز
# --------------------------------------------------------------------------------
# poem_id=97 bayt_id=6
# BAYT: چرا همی‌شکنی جان من ز سنگدلی؟ / دل ضعیف که باشد، به نازکی چو زجاج
# HINT: شکستن دل نازک عاشق به دست معشوق سنگدل
# --------------------------------------------------------------------------------
# poem_id=97 bayt_id=7
# BAYT: لب تو خضر و دهان تو آب حیوان است / قد تو سرو و میان موی و بر، به هییت عاج
# HINT: تشبیه اعضای معشوق به عناصر طبیعی و نفیس
# --------------------------------------------------------------------------------
# poem_id=98 bayt_id=4
# BAYT: ز دیده‌ام شده یک چشمه در کنار روان / که آشنا نکند در میان آن، ملاح
# HINT: چشمه اشک در کنار روان و بیگانگی ملاح
# --------------------------------------------------------------------------------
# poem_id=100 bayt_id=1
# BAYT: دی پیر می‌فروش که ذکرش به خیر باد / گفتا شراب نوش و غم دل ببر ز یاد
# HINT: سخن پیر می‌فروش درباره شراب و فراموشی غم
# --------------------------------------------------------------------------------
# poem_id=100 bayt_id=5
# BAYT: حافظ گرت ز پند حکیمان ملالت است / کوته کنیم قصه، که عمرت دراز باد
# HINT: پیشنهاد کوتاهی سخن به سبب ملالت از پند
# --------------------------------------------------------------------------------
# poem_id=102 bayt_id=6
# BAYT: از دست رفته بود وجود ضعیف من / صبحم به بوی وصل تو جان باز داد، باد
# HINT: بازگشت زندگی به جسم ناتوان با بوی وصال
# --------------------------------------------------------------------------------
# poem_id=103 bayt_id=2
# BAYT: کامم از تلخی غم چون زهر گشت / بانگ نوش شادخواران یاد باد
# HINT: تلخی کام از غم و یاد شادخواری گذشته
# --------------------------------------------------------------------------------
# poem_id=103 bayt_id=4
# BAYT: مبتلا گشتم در این بند و بلا / کوشش آن حق‌گزاران یاد باد
# HINT: گرفتاری در بند و بلا، یاد یاران وفادار
# --------------------------------------------------------------------------------
# poem_id=104 bayt_id=6
# BAYT: چو لعل شکرینت بوسه بخشد / مذاق جان من زو پرشکر باد
# HINT: بوسه بر لعل شیرین و تاثیر بر جان
# --------------------------------------------------------------------------------
# poem_id=105 bayt_id=7
# BAYT: نرگس مست نوازش‌کن مردم‌دارش / خون عاشق به قدح گر بخورد نوشش باد
# HINT: چشم مهربان معشوق و آرزوی خیر برای او
# --------------------------------------------------------------------------------
# poem_id=106 bayt_id=4
# BAYT: در این چمن چو درآید خزان به یغمایی / رهش به سرو سهی قامت بلند مباد
# HINT: دعا برای سلامت سرو بلند در برابر خزان
# --------------------------------------------------------------------------------
# poem_id=112 bayt_id=1
# BAYT: آن که رخسار تو را رنگ گل و نسرین داد / صبر و آرام تواند به من مسکین داد
# HINT: درخواست بخشش صبر و آرامش از بخشنده زیبایی
# --------------------------------------------------------------------------------
# poem_id=113 bayt_id=2
# BAYT: دلم خزانه‌ی اسرار بود و دست قضا / درش ببست و کلیدش به دل‌ستانی داد
# HINT: بسته شدن خزانه اسرار دل به دست تقدیر
# --------------------------------------------------------------------------------
# poem_id=114 bayt_id=3
# BAYT: شبی که ماه مراد از افق شود طالع / بود که پرتو نوری به بام ما افتد
# HINT: طلوع ماه مراد و تابش نور بر بام
# --------------------------------------------------------------------------------
# poem_id=117 bayt_id=4
# BAYT: به چمن خرام و بنگر بر تخت گل که لاله / به ندیم شاه ماند که به کف ایاغ دارد
# HINT: تماشای لاله با جام در دست در چمن
# --------------------------------------------------------------------------------
# poem_id=120 bayt_id=5
# BAYT: چو دام طره افشاند ز گرد خاطر عشاق / به غماز صبا گوید که راز ما نهان دارد
# HINT: افشاندن زلف معشوق و پنهان داشتن راز عاشقان
# --------------------------------------------------------------------------------
# poem_id=120 bayt_id=6
# BAYT: بیفشان جرعه‌ای بر خاک و حال اهل دل بشنو / که از جمشید و کیخسرو، فراوان داستان دارد
# HINT: ریختن شراب بر خاک و یادآوری سرگذشت پادشاهان
# --------------------------------------------------------------------------------
# poem_id=122 bayt_id=1
# BAYT: هر آن‌که جانب اهل خدا نگه دارد / خداش در همه حال از بلا نگه دارد
# HINT: حمایت از اهل خدا و دریافت حمایت الهی
# --------------------------------------------------------------------------------
# poem_id=124 bayt_id=7
# BAYT: چشم مخمور تو دارد ز دلم قصد جگر / ترک مست است مگر میل کبابی دارد
# HINT: نگاه مست معشوق و آسیب به دل عاشق
# --------------------------------------------------------------------------------
# poem_id=127 bayt_id=8
# BAYT: گو برو و آستین به خون جگر شوی / هر که در این آستانه راه ندارد
# HINT: رنج و دشواری راه یافتن به آستان معشوق
# --------------------------------------------------------------------------------
# poem_id=129 bayt_id=5
# BAYT: دل ضعیفم از آن می‌کشد به طرف چمن / که جان ز مرگ به بیماری صبا ببرد
# HINT: کشش دل به سوی چمن به امید نجات
# --------------------------------------------------------------------------------
# poem_id=138 bayt_id=4
# BAYT: دل به امید صدایی که مگر در تو رسد / ناله‌ها کرد در این کوه که فرهاد نکرد
# HINT: ناله عاشقانه در کوه به امید شنیدن پاسخ
# --------------------------------------------------------------------------------
# poem_id=138 bayt_id=8
# BAYT: مطربا پرده بگردان و بزن راه عراق / که بدین راه بشد یار و ز ما یاد نکرد
# HINT: درخواست تغییر نغمه و اشاره به کوچ یار
# --------------------------------------------------------------------------------
# poem_id=140 bayt_id=3
# BAYT: گفتم مگر به گریه دلش مهربان کنم / چون سخت بود در دل سنگش اثر نکرد
# HINT: کوشش برای نرم کردن دل معشوق با گریه
# --------------------------------------------------------------------------------
# poem_id=150 bayt_id=5
# BAYT: روز در کسب هنر کوش که می خوردن روز / دل چون آینه، در زنگ ظلام اندازد
# HINT: کوشش در هنر و پرهیز از می‌خواری روزانه
# --------------------------------------------------------------------------------
# poem_id=153 bayt_id=3
# BAYT: نگارم دوش در مجلس، به عزم رقص چون برخاست / گره بگشود از ابرو و بر دل‌های یاران زد
# HINT: حضور معشوق در مجلس و تاثیر حرکات او
# --------------------------------------------------------------------------------
# poem_id=157 bayt_id=2
# BAYT: من چو از خاک لحد لاله‌صفت برخیزم / داغ سودای توام سر سویدا باشد
# HINT: برخاستن عاشق از خاک با داغ عشق پنهان
# --------------------------------------------------------------------------------
# poem_id=159 bayt_id=7
# BAYT: دلق و سجاده‌ی حافظ ببرد باده‌فروش / گر شرابش ز کف ساقی مه‌وش باشد
# HINT: معاوضه دلق و سجاده با شراب ساقی زیبا
# --------------------------------------------------------------------------------
# poem_id=166 bayt_id=5
# BAYT: آن پریشانی شب‌های دراز و غم دل / همه در سایه‌ی گیسوی نگار آخر شد
# HINT: پایان اندوه و رنج شبانه در پرتو معشوق
# --------------------------------------------------------------------------------
# poem_id=167 bayt_id=10
# BAYT: ز راه میکده یاران عنان بگردانید / چرا که حافظ از این راه رفت و مفلس شد
# HINT: پند به یاران برای پرهیز از راه میکده
# --------------------------------------------------------------------------------
# poem_id=168 bayt_id=3
# BAYT: پیام داد که خواهم نشست با رندان / بشد به رندی و دردی کشیم نام و نشد
# HINT: کوشش برای جلب توجه معشوق با همنشینی رندان
# --------------------------------------------------------------------------------
# poem_id=168 bayt_id=4
# BAYT: رواست در بر اگر می‌تپد کبوتر دل / که دید در ره خود تاب و پیچ دام و نشد
# HINT: کبوتر دل در برابر دام و پیچ راه
# --------------------------------------------------------------------------------
# poem_id=169 bayt_id=5
# BAYT: شهر یاران بود و خاک مهر‌بانان این دیار / مهربانی کی سر آمد؟ شهریار‌ان را چه شد؟
# HINT: یادآوری دوران مهربانی و جستجوی علت زوال بزرگان
# --------------------------------------------------------------------------------
# poem_id=172 bayt_id=1
# BAYT: عشق تو نهال حیرت آمد / وصل تو کمال حیرت آمد
# HINT: رشد و اوج حیرت در پیوند با معشوق
# --------------------------------------------------------------------------------
# poem_id=176 bayt_id=5
# BAYT: مرغ دل باز هوادار کمان‌ابروییست / ای کبوتر نگران باش که شاهین آمد
# HINT: دلبستگی دل به معشوق و هشدار از خطر
# --------------------------------------------------------------------------------
# poem_id=176 bayt_id=6
# BAYT: ساقیا می بده و غم مخور از دشمن و دوست / که به کام دل ما آن بشد و این آمد
# HINT: درخواست باده و بی‌اعتنایی به دشمن و دوست
# --------------------------------------------------------------------------------
# poem_id=177 bayt_id=6
# BAYT: بباختم دل دیوانه و ندانستم / که آدمی‌بچه‌ای، شیوه‌ی پری داند
# HINT: از دست رفتن دل و ناآگاهی از فریبندگی
# --------------------------------------------------------------------------------
# poem_id=183 bayt_id=8
# BAYT: همت حافظ و انفاس سحرخیزان بود / که ز بند غم ایام نجاتم دادند
# HINT: رهایی از غم با یاری همت و دعا
# --------------------------------------------------------------------------------
# poem_id=187 bayt_id=3
# BAYT: ز ملک تا ملکوتش حجاب بردارند / هر آن که خدمت جام جهان‌نما بکند
# HINT: رفع حجاب میان عوالم برای خدمت‌گزار جام جهان‌نما
# --------------------------------------------------------------------------------
# poem_id=187 bayt_id=4
# BAYT: طبیب عشق مسیحا‌دم است و مشفق، لیک / چو درد در تو نبیند که را دوا بکند؟
# HINT: درخواست درمان از طبیب دلسوز در غیاب درد
# --------------------------------------------------------------------------------
# poem_id=191 bayt_id=4
# BAYT: گفتم گره نگشوده‌ام، زان طره تا من بوده‌ام / گفتا منش فرموده‌ام، تا با تو طراری کند
# HINT: گفت‌وگوی عاشق و معشوق درباره گره و موهبت
# --------------------------------------------------------------------------------
# poem_id=191 bayt_id=8
# BAYT: شد لشکر غم بی عدد، از بخت می‌خواهم مدد / تا فخر دین عبدالصمد، باشد که غمخواری کند
# HINT: درخواست یاری از محبوب در برابر اندوه فراوان
# --------------------------------------------------------------------------------
# poem_id=193 bayt_id=3
# BAYT: جلوه‌گاه رخ او، دیده‌ی من، تنها نیست / ماه و خورشید، همین آینه می‌گردانند
# HINT: تماشای جمال معشوق توسط دیدگان و اجرام آسمانی
# --------------------------------------------------------------------------------
# poem_id=193 bayt_id=9
# BAYT: گر به نزهتگه ارواح برد بوی تو، باد / عقل و جان، گوهر هستی به نثار افشانند
# HINT: ایثار عقل و جان در برابر عطر محبوب
# --------------------------------------------------------------------------------
# poem_id=194 bayt_id=5
# BAYT: ز چشمم لعل رمانی چو می‌خندند، می‌بارند / ز رویم راز پنهانی چو می‌بینند، می‌خوانند
# HINT: تجلی راز در چهره و اشک در چشم
# --------------------------------------------------------------------------------
# poem_id=204 bayt_id=8
# BAYT: یاد باد آن که خرابات نشین بودم و مست / وآنچه در مسجدم امروز کم است آنجا بود
# HINT: یادآوری روزگار میخانه و مقایسه با حال مسجد
# --------------------------------------------------------------------------------
# poem_id=205 bayt_id=3
# BAYT: بر سر تربت ما چون گذری همت خواه / که زیارتگه رندان جهان خواهد بود
# HINT: درخواست توجه به مزار و پیش‌بینی اهمیت آینده
# --------------------------------------------------------------------------------
# poem_id=206 bayt_id=9
# BAYT: در شب قدر ار صبوحی کرده‌ام، عیبم مکن / سرخوش آمد یار و جامی بر کنار طاق بود
# HINT: حضور یار و جام می در شب قدر
# --------------------------------------------------------------------------------
# poem_id=207 bayt_id=1
# BAYT: یاد باد آن که سر کوی توام منزل بود / دیده را روشنی از خاک درت حاصل بود
# HINT: یادآوری روزگار گذشته و اقامت در کوی معشوق
# --------------------------------------------------------------------------------
# poem_id=212 bayt_id=3
# BAYT: در مقامات طریقت هر کجا کردیم سیر / عافیت را با نظربازی فراق افتاده بود
# HINT: سیر در مقامات طریقت و مواجهه با فراق
# --------------------------------------------------------------------------------
# poem_id=215 bayt_id=1
# BAYT: به کوی میکده یا رب سحر چه مشغله بود؟ / که جوش شاهد و ساقی و شمع و مشعله بود
# HINT: محفل میخانه و شور و شوق اهل طرب
# --------------------------------------------------------------------------------
# poem_id=215 bayt_id=4
# BAYT: دل از کرشمه‌ی ساقی به شکر بود ولی / ز نامساعدی بختش اندکی گله بود
# HINT: رضایت از لطف ساقی و گلایه از بخت
# --------------------------------------------------------------------------------
# poem_id=226 bayt_id=2
# BAYT: گویند سنگ لعل شود در مقام صبر / آری شود، ولیک به خون جگر شود
# HINT: تبدیل سنگ به لعل با صبر و رنج
# --------------------------------------------------------------------------------
# poem_id=226 bayt_id=6
# BAYT: از کیمیای مهر تو زر گشت روی من / آری به یمن لطف شما خاک زر شود
# HINT: تبدیل چهره زرد به زر به واسطه مهر
# --------------------------------------------------------------------------------
# poem_id=230 bayt_id=4
# BAYT: مقیم حلقه‌ی ذکر است دل بدان امید / که حلقه‌ای ز سر زلف یار بگشاید
# HINT: اقامت دل در جمع ذاکران با آرزوی وصال
# --------------------------------------------------------------------------------
# poem_id=230 bayt_id=6
# BAYT: چمن خوش است و هوا دلکش است و می بی‌غش / کنون به جز دل خوش هیچ در نمی‌باید
# HINT: وصف طبیعت دلپذیر و توصیه به دل خوش
# --------------------------------------------------------------------------------
# poem_id=231 bayt_id=1
# BAYT: گفتم غم تو دارم گفتا غمت سرآید / گفتم که ماه من شو گفتا اگر برآید
# HINT: گفت‌وگوی عاشق و معشوق درباره وصال و اندوه
# --------------------------------------------------------------------------------
# poem_id=231 bayt_id=6
# BAYT: گفتم که نوش لعلت ما را به آرزو کشت / گفتا تو بندگی کن کاو بنده‌پرور آید
# HINT: گفت‌وگوی عاشق و معشوق درباره آرزو و بندگی
# --------------------------------------------------------------------------------
# poem_id=234 bayt_id=6
# BAYT: گرت چو نوح نبی صبر هست در غم طوفان / بلا بگردد و کام هزارساله برآید
# HINT: صبر در رنج و پاداش پس از بلا
# --------------------------------------------------------------------------------
# poem_id=236 bayt_id=7
# BAYT: مانعش غلغل چنگ است و شکرخواب صبوح / ور نه گر بشنود آه سحرم بازآید
# HINT: مانع بازگشت معشوق، صدای چنگ و لذت باده‌گساری
# --------------------------------------------------------------------------------
# poem_id=237 bayt_id=8
# BAYT: در این خیال به سر شد زمان عمر و هنوز / بلای زلف سیاهت به سر نمی‌آید
# HINT: ادامه رنج هجران و گذر عمر در خیال
# --------------------------------------------------------------------------------
# poem_id=238 bayt_id=2
# BAYT: شکسته گشت چو پشت هلال قامت من / کمان ابروی یارم چو وسمه بازکشید
# HINT: شکستگی قامت عاشق و نمودار شدن ابروی معشوق
# --------------------------------------------------------------------------------
# poem_id=240 bayt_id=2
# BAYT: شاهدان در جلوه و من شرمسار کیسه‌ام / بار عشق و مفلسی صعب است، می‌باید کشید
# HINT: شرمساری در برابر زیبایی و تحمل فقر عاشقانه
# --------------------------------------------------------------------------------
# poem_id=240 bayt_id=6
# BAYT: دامنی گر چاک شد در عالم رندی چه باک / جامه‌ای در نیکنامی نیز می‌باید درید
# HINT: چاک شدن دامن رندی و دریدن جامه نیکنامی
# --------------------------------------------------------------------------------
# poem_id=240 bayt_id=9
# BAYT: تیر عاشق‌کش ندانم بر دل حافظ که زد / این قدر دانم که از شعر ترش خون می‌چکید
# HINT: زخم دل عاشق و تاثیر آن در شعر
# --------------------------------------------------------------------------------
# poem_id=243 bayt_id=2
# BAYT: ای شاه حسن، چشم به حال گدا فکن / کاین گوش بس حکایت شاه و گدا شنید
# HINT: درخواست توجه از مقام والا به فرو دست
# --------------------------------------------------------------------------------
# poem_id=245 bayt_id=7
# BAYT: سکندر را نمی‌بخشند آبی / به زور و زر میسر نیست این کار
# HINT: ناتوانی قدرت و ثروت در دستیابی به مطلوب
# --------------------------------------------------------------------------------
# poem_id=245 bayt_id=9
# BAYT: بت چینی عدوی دین و دل‌هاست / خداوندا دل و دینم نگه دار
# HINT: درخواست حفظ ایمان و دل از خطر دشمن
# --------------------------------------------------------------------------------
# poem_id=255 bayt_id=8
# BAYT: گرچه منزل بس خطرناک است و مقصد بس بعید / هیچ راهی نیست که آن را نیست پایان، غم مخور
# HINT: توصیف دشواری راه و امید به پایان آن
# --------------------------------------------------------------------------------
# poem_id=256 bayt_id=5
# BAYT: بر آن سرم که ننوشم می و گنه نکنم / اگر موافق تدبیر من شود تقدیر
# HINT: ترک گناه و می‌خواری در صورت موافقت تقدیر
# --------------------------------------------------------------------------------
# poem_id=256 bayt_id=10
# BAYT: می دوساله و محبوب چارده ساله / همین بس است مرا صحبت صغیر و کبیر
# HINT: رضایت به همنشینی با شراب و محبوب جوان
# --------------------------------------------------------------------------------
# poem_id=257 bayt_id=4
# BAYT: چنگ بنواز و بساز ار نبود عود چه باک؟ / آتشم عشق و دلم عود و تنم مجمر گیر
# HINT: تشبیه دل به عود و تن به مجمر
# --------------------------------------------------------------------------------
# poem_id=257 bayt_id=6
# BAYT: صوف برکش ز سر و باده‌ی صافی درکش / سیم در باز و به زر سیمبری در بر گیر
# HINT: ترک تعلقات دنیوی و استقبال از لذت معنوی
# --------------------------------------------------------------------------------
# poem_id=261 bayt_id=1
# BAYT: درآ که در دل خسته توان درآید باز / بیا که در تن مرده روان درآید باز
# HINT: درخواست حضور محبوب برای احیای دل و جان
# --------------------------------------------------------------------------------
# poem_id=261 bayt_id=3
# BAYT: غمی که چون سپه زنگ، ملک دل بگرفت / ز خیل شادی روم رخت زداید باز
# HINT: تسلط غم بر دل و انتظار بازگشت شادی
# --------------------------------------------------------------------------------
# poem_id=264 bayt_id=5
# BAYT: دل ما را که ز مار سر زلف تو بخست / از لب خود به شفاخانه‌ی تریاک انداز
# HINT: زخم دل از زلف معشوق و درخواست شفا
# --------------------------------------------------------------------------------
# poem_id=265 bayt_id=9
# BAYT: در قلم آورد حافظ قصه‌ی لعل لبش / آب حیوان می‌رود هر دم ز اقلامم هنوز
# HINT: کوشش در ثبت زیبایی و زوال تدریجی اثر
# --------------------------------------------------------------------------------
# poem_id=267 bayt_id=5
# BAYT: عشرت شب‌گیر کن، می نوش کاندر راه عشق / شب‌روان را آشنایی‌هاست با میر عسس
# HINT: عیش شبانه و همراهی شب‌روان در راه عشق
# --------------------------------------------------------------------------------
# poem_id=268 bayt_id=3
# BAYT: قصر فردوس به پاداش عمل می‌بخشند / ما که رندیم و گدا، دیر مغان ما را بس
# HINT: قناعت به میخانه و بی‌نیازی از پاداش اخروی
# --------------------------------------------------------------------------------
# poem_id=269 bayt_id=2
# BAYT: دگر ز منزل جانان سفر مکن درویش / که سیر معنوی و کنج خانقاهت بس
# HINT: پند به ترک سفر و قناعت به خانقاه
# --------------------------------------------------------------------------------
# poem_id=272 bayt_id=1
# BAYT: باز آی و دل تنگ مرا مونس جان باش / وین سوخته را محرم اسرار نهان باش
# HINT: درخواست بازگشت یار و همدلی با دل تنگ
# --------------------------------------------------------------------------------
# poem_id=276 bayt_id=5
# BAYT: با چنین زلف و رخش بادا نظربازی حرام / هر که روی یاسمین و جعد سنبل بایدش
# HINT: توصیف زیبایی معشوق و تاثیر آن بر دل
# --------------------------------------------------------------------------------
# poem_id=277 bayt_id=5
# BAYT: ای که در کوچه‌ی معشوقه‌ی ما می‌گذری / بر حذر باش، که سر می‌شکند دیوارش
# HINT: هشدار به رهگذر در گذر از کوچه معشوق
# --------------------------------------------------------------------------------
# poem_id=278 bayt_id=3
# BAYT: بیاور می که نتوان شد ز مکر آسمان ایمن / به لعب زهره‌ی چنگی و مریخ سلحشورش
# HINT: پناه بردن به شراب در برابر نیرنگ آسمان
# --------------------------------------------------------------------------------
# poem_id=280 bayt_id=1
# BAYT: چو برشکست صبا زلف عنبرافشانش / به هر شکسته که پیوست تازه شد جانش
# HINT: وزش نسیم بر زلف معشوق و تجدید جان
# --------------------------------------------------------------------------------
# poem_id=280 bayt_id=7
# BAYT: بگیرم آن سر زلف و به دست خواجه دهم / که سوخت حافظ بی‌دل ز مکر و دستانش
# HINT: گرفتن زلف معشوق و سپردن به دست او
# --------------------------------------------------------------------------------
# poem_id=281 bayt_id=1
# BAYT: یا رب این نوگل خندان که سپردی به منش / می‌سپارم به تو از چشم حسود چمنش
# HINT: سپردن گل به خداوند برای حفظ از حسودان
# --------------------------------------------------------------------------------
# poem_id=282 bayt_id=1
# BAYT: ببرد از من قرار و طاقت و هوش / بت سنگین دل سیمین بناگوش
# HINT: سلب آرامش و توان از عاشق توسط معشوق
# --------------------------------------------------------------------------------
# poem_id=283 bayt_id=5
# BAYT: ز کوی میکده دوشش به دوش می‌بردند / امام شهر که سجاده می‌کشید به دوش
# HINT: حمل امام شهر بر دوش مردم از میکده
# --------------------------------------------------------------------------------
# poem_id=285 bayt_id=1
# BAYT: در عهد پادشاه خطابخش جرم پوش / حافظ قرابه کش شد و مفتی پیاله نوش
# HINT: پناه بردن به می‌خواری در سایه عفو شاهانه
# --------------------------------------------------------------------------------
# poem_id=285 bayt_id=6
# BAYT: عشق است و مفلسی و جوانی و نوبهار / عذرم پذیر و جرم به ذیل کرم بپوش
# HINT: درخواست بخشش در جوانی و فقر و عشق
# --------------------------------------------------------------------------------
# poem_id=286 bayt_id=6
# BAYT: گوش کن پند ای پسر وز بهر دنیا غم مخور / گفتمت چون در حدیثی، گر توانی داشت هوش
# HINT: نصیحت پدرانه و دعوت به بی‌اعتنایی به دنیا
# --------------------------------------------------------------------------------
# poem_id=286 bayt_id=8
# BAYT: بر بساط نکته‌دانان خودفروشی شرط نیست / یا سخن دانسته گو ای مرد عاقل، یا خموش
# HINT: محفل دانایان و ضرورت سکوت یا سخن سنجیده
# --------------------------------------------------------------------------------
# poem_id=290 bayt_id=4
# BAYT: بنازم آن مژه‌ی شوخ عافیت کش را / که موج می‌زندش آب نوش، بر سر نیش
# HINT: مژه بی‌رحم و آب حیات بر نوک آن
# --------------------------------------------------------------------------------
# poem_id=296 bayt_id=9
# BAYT: حافظ اگر قدم زنی، در ره خاندان به صدق / بدرقه‌ی رهت شود، همت شحنه‌ی نجف
# HINT: سفر راستین در مسیر خاندان با همراهی همت
# --------------------------------------------------------------------------------
# poem_id=298 bayt_id=5
# BAYT: بیا که توبه ز لعل نگار و خنده‌ی جام / حکایتیست که عقلش نمی‌کند تصدیق
# HINT: تردید عقل در برابر جذابیت معشوق و شراب
# --------------------------------------------------------------------------------
# poem_id=298 bayt_id=8
# BAYT: اگر به رنگ عقیقی شد اشک من، چه عجب؟ / که مهر خاتم لعل تو هست همچو عقیق
# HINT: تشبیه اشک به عقیق و مهر به خاتم
# --------------------------------------------------------------------------------
# poem_id=311 bayt_id=1
# BAYT: عاشق روی جوانی خوش نوخاسته‌ام / وز خدا دولت این غم به دعا خواسته‌ام
# HINT: دلبستگی به معشوق جوان و آرزوی غم عشق
# --------------------------------------------------------------------------------
# poem_id=313 bayt_id=1
# BAYT: بازآی ساقیا که هواخواه خدمتم / مشتاق بندگی و دعاگوی دولتم
# HINT: درخواست بازگشت ساقی و اظهار اشتیاق به خدمت
# --------------------------------------------------------------------------------
# poem_id=316 bayt_id=2
# BAYT: می مخور با همه کس تا نخورم خون جگر / سر مکش تا نکشد سر به فلک فریادم
# HINT: نهی از معاشرت با نااهلان و درخواست وفاداری
# --------------------------------------------------------------------------------
# poem_id=316 bayt_id=7
# BAYT: شهره‌ی شهر مشو تا ننهم سر در کوه / شور شیرین منما تا نکنی فرهادم
# HINT: هشدار به معشوق درباره رفتار و پیامدهای آن
# --------------------------------------------------------------------------------
# poem_id=317 bayt_id=4
# BAYT: سایه‌ی طوبی و دلجویی حور و لب حوض / به هوای سر کوی تو برفت از یادم
# HINT: فراموشی نعمت‌های بهشتی به سبب دلبستگی به معشوق
# --------------------------------------------------------------------------------
# poem_id=318 bayt_id=6
# BAYT: شبی دل را به تاریکی ز زلفت باز می‌جستم / رخت می‌دیدم و جامی هلالی باز می‌خوردم
# HINT: جستجوی دل و مشاهده رخ و نوشیدن باده
# --------------------------------------------------------------------------------
# poem_id=325 bayt_id=8
# BAYT: دامن مفشان از من خاکی که پس از من / زین در نتواند که برد باد غبارم
# HINT: اشاره به فناپذیری و بی‌اثری پس از مرگ
# --------------------------------------------------------------------------------
# poem_id=328 bayt_id=5
# BAYT: خرم آن روز کز این مرحله بربندم بار / و از سر کوی تو پرسند رفیقان خبرم
# HINT: آرزوی رهایی از دنیا و پیوستن به معشوق
# --------------------------------------------------------------------------------
# poem_id=329 bayt_id=5
# BAYT: شاها اگر به عرش رسانم سریر فضل / مملوک این جنابم و مسکین این درم
# HINT: اظهار بندگی و فروتنی در برابر مرجع برتر
# --------------------------------------------------------------------------------
# poem_id=329 bayt_id=7
# BAYT: ور باورت نمی‌کند از بنده این حدیث / از گفته‌ی کمال، دلیلی بیاورم
# HINT: درخواست پذیرش سخن با استناد به مرجع معتبر
# --------------------------------------------------------------------------------
# poem_id=329 bayt_id=21
# BAYT: شبل الاسد به صید دلم حمله کرد و من / گر لاغرم وگرنه شکار غضنفرم
# HINT: حمله شیر به دل و توصیف ضعف شکار
# --------------------------------------------------------------------------------
# poem_id=330 bayt_id=1
# BAYT: تو همچو صبحی و من شمع خلوت سحرم / تبسمی کن و جان بین که چون همی‌سپرم
# HINT: تشبیه معشوق به صبح و عاشق به شمع
# --------------------------------------------------------------------------------
# poem_id=330 bayt_id=4
# BAYT: چه شکر گویمت ای خیل غم، عفاک الله / که روز بی‌کسی آخر نمی‌روی ز سرم
# HINT: گفت‌وگو با غم و گلایه از ماندگاری آن
# --------------------------------------------------------------------------------
# poem_id=331 bayt_id=3
# BAYT: غم گیتی گر از پایم درآرد / بجز ساغر که باشد دستگیرم؟
# HINT: درخواست یاری از شراب در برابر غم دنیا
# --------------------------------------------------------------------------------
# poem_id=334 bayt_id=3
# BAYT: پروانه‌ی راحت بده ای شمع که امشب / از آتش دل پیش تو چون شمع گدازم
# HINT: درخواست آرامش از معشوق در حال سوختن عاشق
# --------------------------------------------------------------------------------
# poem_id=334 bayt_id=5
# BAYT: چون نیست نماز من آلوده نمازی / در میکده زان کم نشود سوز و گدازم
# HINT: اظهار ناتوانی در عبادت پاک، بیان سوز درونی
# --------------------------------------------------------------------------------
# poem_id=335 bayt_id=1
# BAYT: در خرابات مغان گر گذر افتد بازم / حاصل خرقه و سجاده، روان دربازم
# HINT: ورود به میخانه و رها کردن تعلقات ظاهری
# --------------------------------------------------------------------------------
# poem_id=335 bayt_id=6
# BAYT: مرغ سان از قفس خاک هوایی گشتم / به هوایی که مگر صید کند شهبازم
# HINT: آزادی از قفس خاکی و جستجوی افق نو
# --------------------------------------------------------------------------------
# poem_id=337 bayt_id=3
# BAYT: ز محرمان سراپرده‌ی وصال شوم / ز بندگان خداوندگار خود باشم
# HINT: ورود به جمع مقربان و پیوستن به محبوب
# --------------------------------------------------------------------------------
# poem_id=340 bayt_id=8
# BAYT: من که خواهم که ننوشم به جز از راوق خم / چه کنم گر سخن پیر مغان ننیوشم؟
# HINT: تردید میان خواسته شخصی و سخن پیر مغان
# --------------------------------------------------------------------------------
# poem_id=346 bayt_id=7
# BAYT: چون صبا مجموعه‌ی گل را به آب لطف شست / کج دلم خوان، گر نظر بر صفحه‌ی دفتر کنم
# HINT: شست‌وشوی گل‌ها با نسیم و تامل در دفتر
# --------------------------------------------------------------------------------
# poem_id=348 bayt_id=1
# BAYT: دیده دریا کنم و صبر به صحرا فکنم / واندر این کار دل خویش به دریا فکنم
# HINT: رهایی از صبر و سپردن دل به دریا
# --------------------------------------------------------------------------------
# poem_id=349 bayt_id=1
# BAYT: دوش سودای رخش گفتم ز سر بیرون کنم / گفت کو زنجیر؟ تا تدبیر این مجنون کنم
# HINT: گفت‌وگوی خیالی با معشوق درباره رهایی از دلبستگی
# --------------------------------------------------------------------------------
# poem_id=349 bayt_id=2
# BAYT: قامتش را سرو گفتم، سر کشید از من به خشم / دوستان از راست می‌رنجد نگارم، چون کنم؟
# HINT: تشبیه قامت معشوق به سرو و رنجش معشوق
# --------------------------------------------------------------------------------
# poem_id=349 bayt_id=5
# BAYT: ای نسیم منزل لیلی خدا را تا به کی / ربع را برهم زنم، اطلال را جیحون کنم
# HINT: خطاب به نسیم، یادآوری دیار معشوق، آشفتگی خاطر
# --------------------------------------------------------------------------------
# poem_id=349 bayt_id=6
# BAYT: من که ره بردم به گنج حسن بی‌پایان دوست / صد گدای همچو خود را بعد از این قارون کنم
# HINT: دستیابی به گنجینه محبوب و بخشش به دیگران
# --------------------------------------------------------------------------------
# poem_id=350 bayt_id=5
# BAYT: ز روی دوست مرا چون گل مراد شکفت / حواله‌ی سر دشمن به سنگ خاره کنم
# HINT: شکفتگی دل از دیدار معشوق و تهدید دشمن
# --------------------------------------------------------------------------------
# poem_id=351 bayt_id=3
# BAYT: از قیل و قال مدرسه حالی دلم گرفت / یک چند نیز خدمت معشوق و می کنم
# HINT: دلزدگی از مدرسه و تمایل به معشوق و می
# --------------------------------------------------------------------------------
# poem_id=354 bayt_id=7
# BAYT: صباح الخیر زد بلبل، کجایی ساقیا؟ برخیز / که غوغا می‌کند در سر خیال خواب دوشینم
# HINT: آغاز صبح و آشفتگی خاطر از رؤیای شبانه
# --------------------------------------------------------------------------------
# poem_id=355 bayt_id=9
# BAYT: بر دلم گرد ستم‌هاست خدایا مپسند / که مکدر شود آیینه مهرآیینم
# HINT: دل آزرده از ستم و بیم تیرگی مهر
# --------------------------------------------------------------------------------
# poem_id=356 bayt_id=3
# BAYT: مگر دیوانه خواهم شد در این سودا که شب تا روز / سخن با ماه می‌گویم، پری در خواب می‌بینم
# HINT: گفتگو با ماه و رؤیت پری در خواب
# --------------------------------------------------------------------------------
# poem_id=358 bayt_id=8
# BAYT: نشان موی میانش که دل در او بستم / ز من مپرس که خود در میان نمی‌بینم
# HINT: دلبستگی به معشوق و محو شدن در او
# --------------------------------------------------------------------------------
# poem_id=359 bayt_id=2
# BAYT: گر چه دانم که به جایی نبرد راه غریب / من به بوی سر آن زلف پریشان بروم
# HINT: حرکت در مسیر ناآشنا به امید نشانه معشوق
# --------------------------------------------------------------------------------
# poem_id=364 bayt_id=7
# BAYT: گفتی که «حافظ این همه رنگ و خیال چیست؟!» / نقش غلط مبین که همان لوح ساده‌ایم
# HINT: پرسش از صداقت و پاسخ به اتهام ریا
# --------------------------------------------------------------------------------
# poem_id=367 bayt_id=10
# BAYT: دام سخت است مگر یار شود لطف خدا / ور نه آدم نبرد صرفه ز شیطان رجیم
# HINT: درخواست یاری الهی در برابر دشواری و وسوسه
# --------------------------------------------------------------------------------
# poem_id=370 bayt_id=1
# BAYT: صلاح از ما چه می‌جویی؟ که مستان را صلا گفتیم / به دور نرگس مستت سلامت را دعا گفتیم
# HINT: خطاب به معشوق و بیان دعا برای مستان
# --------------------------------------------------------------------------------
# poem_id=371 bayt_id=3
# BAYT: سلطان ازل گنج غم عشق به ما داد / تا روی در این منزل ویرانه نهادیم
# HINT: بخشش گنج غم عشق از سوی سلطان ازل
# --------------------------------------------------------------------------------
# poem_id=372 bayt_id=7
# BAYT: از جرعه تو خاک زمین در و لعل یافت / بیچاره ما که پیش تو از خاک کمتریم
# HINT: مقایسه ارزش خاک و انسان در برابر محبوب
# --------------------------------------------------------------------------------
# poem_id=374 bayt_id=5
# BAYT: صبا خاک وجود ما بدان عالی‌جناب انداز / بود کان شاه خوبان را نظر بر منظر اندازیم
# HINT: درخواست واسطه‌گری باد صبا برای تقرب به معشوق
# --------------------------------------------------------------------------------
# poem_id=375 bayt_id=4
# BAYT: بیرون جهیم سرخوش و از بزم صوفیان / غارت کنیم باده و شاهد به بر کشیم
# HINT: ترک مجلس صوفیان و همراهی با شراب و معشوق
# --------------------------------------------------------------------------------
# poem_id=376 bayt_id=2
# BAYT: نیست در کس کرم و وقت طرب می‌گذرد / چاره آن است که سجاده به می بفروشیم
# HINT: نبود کرم در مردم و گذر زمان خوشی
# --------------------------------------------------------------------------------
# poem_id=377 bayt_id=7
# BAYT: دلم از پرده بشد حافظ خوش‌گوی کجاست / تا به قول و غزلش ساز نوایی بکنیم
# HINT: آزادی دل از حجاب و جستجوی حضور شاعر
# --------------------------------------------------------------------------------
# poem_id=389 bayt_id=5
# BAYT: تنت در جامه چون در جام باده / دلت در سینه چون در سیم آهن
# HINT: تشبیه بدن و دل به ظرف و محتوا
# --------------------------------------------------------------------------------
# poem_id=392 bayt_id=3
# BAYT: خواهم شدن به بستان، چون غنچه با دل تنگ / وآنجا به نیک‌نامی، پیراهنی دریدن
# HINT: رفتن به باغ با دل تنگ و پیراهن دریدن
# --------------------------------------------------------------------------------
# poem_id=395 bayt_id=3
# BAYT: ایام گل، چو عمر به رفتن شتاب کرد / ساقی به دور باده‌ی گلگون، شتاب کن
# HINT: شتاب زمان و دعوت به بهره‌گیری از لذت
# --------------------------------------------------------------------------------
# poem_id=395 bayt_id=4
# BAYT: بگشا به شیوه، نرگس پرخواب مست را / وز رشک، چشم نرگس رعنا به خواب کن
# HINT: درخواست بیداری چشم معشوق و غلبه بر رقیب
# --------------------------------------------------------------------------------
# poem_id=397 bayt_id=8
# BAYT: فضول نفس حکایت بسی کند ساقی / تو کار خود مده از دست و می به ساغر کن
# HINT: گفتگوی نفس و دعوت به توجه به حال
# --------------------------------------------------------------------------------
# poem_id=398 bayt_id=3
# BAYT: برگ نوا تبه شد و ساز طرب نماند / ای چنگ ناله برکش و ای دف خروش کن
# HINT: فقدان شادی و دعوت به ناله و خروش
# --------------------------------------------------------------------------------
# poem_id=398 bayt_id=9
# BAYT: سرمست در قبای زرافشان چو بگذری / یک بوسه نذر حافظ پشمینه‌پوش کن
# HINT: درخواست توجه از معشوق جلیل توسط عارف فروتن
# --------------------------------------------------------------------------------
# poem_id=406 bayt_id=1
# BAYT: گفتا برون شدی به تماشای ماه نو / از ماه ابروان منت شرم باد رو
# HINT: سرزنش تماشای ماه نو در برابر زیبایی معشوق
# --------------------------------------------------------------------------------
# poem_id=406 bayt_id=6
# BAYT: شکل هلال هر سر مه می‌دهد نشان / از افسر سیامک و ترک کلاه زو
# HINT: تشبیه هلال ماه به کلاه و افسر اسطوره‌ای
# --------------------------------------------------------------------------------
# poem_id=407 bayt_id=2
# BAYT: گفتم ای بخت بخفتیدی و خورشید دمید / گفت با این همه از سابقه نومید مشو
# HINT: گفت‌وگوی بخت و شاعر درباره فرصت و امید
# --------------------------------------------------------------------------------
# poem_id=412 bayt_id=7
# BAYT: تو کافر‌دل نمی‌بندی نقاب زلف و می‌ترسم / که محرابم بگرداند خم آن دل‌ستان ابرو
# HINT: آشکار شدن چهره معشوق و بیم دگرگونی دل
# --------------------------------------------------------------------------------
# poem_id=413 bayt_id=1
# BAYT: خط عذار یار که بگرفت ماه از او / خوش حلقه‌ای‌ست لیک به در نیست راه از او
# HINT: حلقه خط چهره یار و انسداد راه رهایی
# --------------------------------------------------------------------------------
# poem_id=416 bayt_id=3
# BAYT: به یاد شخص نزارم که غرق خون دل است / هلال را ز کنار افق کنید نگاه
# HINT: یادآوری معشوق رنجور و اشاره به هلال ماه
# --------------------------------------------------------------------------------
# poem_id=417 bayt_id=2
# BAYT: ای بخت سرکش! تنگش به بر کش / گه جام زرکش، گه لعل دل‌خواه
# HINT: خطاب به بخت سرکش و بیان دگرگونی نعمت‌ها
# --------------------------------------------------------------------------------
# poem_id=417 bayt_id=7
# BAYT: شوق لبت برد، از یاد حافظ / درس شبانه، ورد سحرگاه
# HINT: فراموشی ذکر و درس به سبب شوق معشوق
# --------------------------------------------------------------------------------
# poem_id=418 bayt_id=2
# BAYT: آیین تقوا ما نیز دانیم / لیکن چه چاره با بخت گمراه؟
# HINT: آگاهی از تقوا و ناتوانی در برابر بخت
# --------------------------------------------------------------------------------
# poem_id=421 bayt_id=5
# BAYT: گرفته ساغر عشرت فرشته‌ی رحمت / ز جرعه بر رخ حور و پری گلاب زده
# HINT: پاشیدن شراب شادی بر چهره حور و پری
# --------------------------------------------------------------------------------
# poem_id=422 bayt_id=5
# BAYT: آفرین بر دل نرم تو که از بهر ثواب / کشته‌ی غمزه‌ی خود را به نماز آمده‌ای
# HINT: ستایش دل مهربان معشوق در برابر عاشق جان‌باخته
# --------------------------------------------------------------------------------
# poem_id=423 bayt_id=1
# BAYT: دوش رفتم به در میکده خواب‌آلوده / خرقه تر دامن و سجاده شراب‌آلوده
# HINT: ورود به میکده با لباس و سجاده آلوده
# --------------------------------------------------------------------------------
# poem_id=429 bayt_id=3
# BAYT: هشیار شو که مرغ چمن مست گشت هان / بیدار شو که خواب عدم در پی است هی
# HINT: هشدار به بیداری و آگاهی از گذر زمان
# --------------------------------------------------------------------------------
# poem_id=429 bayt_id=4
# BAYT: خوش نازکانه می‌چمی ای شاخ نوبهار / کآشفتگی مبادت از آشوب باد دی
# HINT: لطافت شاخه بهاری در برابر تهدید باد زمستانی
# --------------------------------------------------------------------------------
# poem_id=430 bayt_id=3
# BAYT: چو گل نقاب برافکند و مرغ زد هوهو / منه ز دست پیاله، چه می‌کنی؟ هی‌هی
# HINT: نمایش زیبایی گل و آواز پرنده در بهار
# --------------------------------------------------------------------------------
# poem_id=431 bayt_id=3
# BAYT: لبش می‌بوسد و خون می‌خورد جام / رخش می‌بیند و گل می‌کند خوی
# HINT: تماس لب و جام، تماشای رخ و شکفتگی خوی
# --------------------------------------------------------------------------------
# poem_id=431 bayt_id=6
# BAYT: گل از خلوت به باغ آورد مسند / بساط زهد همچون غنچه کن طی
# HINT: ورود گل به باغ و آمادگی فضای زهد
# --------------------------------------------------------------------------------
# poem_id=433 bayt_id=7
# BAYT: خواب بیداران ببستی وآن گه از نقش خیال / تهمتی بر شب‌روان خیل خواب انداختی
# HINT: بستن خواب بر بیداران و اتهام به شب‌روان
# --------------------------------------------------------------------------------
# poem_id=436 bayt_id=6
# BAYT: تا کی غم دنیای دنی ای دل دانا؟ / حیف است ز خوبی که شود عاشق زشتی
# HINT: سرزنش دل دانا به سبب دلبستگی به دنیا
# --------------------------------------------------------------------------------
# poem_id=437 bayt_id=2
# BAYT: انفاس عیسی از لب لعلت لطیفه‌ای / آب خضر ز نوش لبانت کنایتی
# HINT: تشبیه لب معشوق به سرچشمه حیات و اعجاز
# --------------------------------------------------------------------------------
# poem_id=437 bayt_id=9
# BAYT: دانی مراد حافظ از این درد و غصه چیست؟ / از تو کرشمه‌ای و ز خسرو عنایتی
# HINT: بیان نیاز به توجه معشوق و عنایت خسرو
# --------------------------------------------------------------------------------
# poem_id=440 bayt_id=4
# BAYT: الا ای یوسف مصری، که کردت سلطنت مغرور / پدر را باز پرس آخر، کجا شد مهر فرزندی؟
# HINT: سرزنش فرزند به سبب غفلت از مهر پدری
# --------------------------------------------------------------------------------
# poem_id=441 bayt_id=4
# BAYT: گرم زمانه سرافراز داشتی و عزیز / سریر عزتم آن خاک آستان بودی
# HINT: ارجاع به عزت و منزلت وابسته به آستان
# --------------------------------------------------------------------------------
# poem_id=446 bayt_id=3
# BAYT: در آن شمایل مطبوع هیچ نتوان گفت / جز این قدر که رقیبان تندخو داری
# HINT: اشاره به زیبایی محبوب و وجود رقیبان تندخو
# --------------------------------------------------------------------------------
# poem_id=452 bayt_id=10
# BAYT: چو مستعد نظر نیستی وصال مجوی / که جام جم نکند سود وقت بی‌بصری
# HINT: ناتوانی از درک حقیقت و بی‌ثمر بودن جستجو
# --------------------------------------------------------------------------------
# poem_id=459 bayt_id=7
# BAYT: بازآ که چشم بد ز رخت دفع می‌کند / ای تازه گل که دامن از این خار می‌کشی
# HINT: درخواست بازگشت معشوق و توصیف دوری از آزار
# --------------------------------------------------------------------------------
# poem_id=461 bayt_id=4
# BAYT: که را رسد که کند عیب دامن پاکت؟ / که همچو قطره که بر برگ گل چکد پاکی
# HINT: تشبیه پاکی معشوق به قطره بر برگ گل
# --------------------------------------------------------------------------------
# poem_id=461 bayt_id=6
# BAYT: صبا عبیرفشان گشت ساقیا برخیز / و هات شمسة کرم مطیب زاکی
# HINT: درخواست باده از ساقی در حضور نسیم بهاری
# --------------------------------------------------------------------------------
# poem_id=462 bayt_id=3
# BAYT: می ده که گرچه گشتم نامه‌سیاه عالم / نومید کی توان بود از لطف لایزالی
# HINT: امیدواری به لطف الهی در اوج سیاهی احوال
# --------------------------------------------------------------------------------
# poem_id=462 bayt_id=4
# BAYT: ساقی بیار جامی و از خلوتم برون کش / تا در به در بگردم قلاش و لاابالی
# HINT: درخواست رهایی از خلوت و پیوستن به جمع
# --------------------------------------------------------------------------------
# poem_id=465 bayt_id=7
# BAYT: حافظ مدار امید فرج از مدار چرخ / دارد هزار عیب و ندارد تفضلی
# HINT: نهی از امیدواری به بهبود اوضاع از فلک
# --------------------------------------------------------------------------------
# poem_id=466 bayt_id=7
# BAYT: چون پیر شدی حافظ از میکده بیرون آی / رندی و هوسناکی در عهد شباب اولی
# HINT: یادآوری دوران جوانی و ترک میکده در پیری
# --------------------------------------------------------------------------------
# poem_id=467 bayt_id=5
# BAYT: گله از زاهد بدخو نکنم؛ رسم این است / که چو صبحی بدمد، در پی‌اش افتد شامی
# HINT: مقایسه رفتار زاهد با گردش شب و روز
# --------------------------------------------------------------------------------
# poem_id=469 bayt_id=4
# BAYT: اذا تغرد عن ذی الاراک طایر خیر / فلا تفرد عن روضها انین حمامی
# HINT: دوری پرنده از باغ و ماندن ناله کبوتران
# --------------------------------------------------------------------------------
# poem_id=470 bayt_id=2
# BAYT: چشم آسایش که دارد از سپهر تیزرو؟ / ساقیا جامی به من ده تا بیاسایم دمی
# HINT: درخواست آسایش از ساقی در برابر بی‌ثباتی روزگار
# --------------------------------------------------------------------------------
# poem_id=472 bayt_id=8
# BAYT: از گل پارسیم غنچه‌ی عیشی نشکفت / حبذا دجله بغداد و می ریحانی
# HINT: حسرت بر شادی ناکام و ستایش نعمت‌های بغداد
# --------------------------------------------------------------------------------
# poem_id=479 bayt_id=4
# BAYT: ساقی به دست باش که غم در کمین ماست / مطرب نگاه دار همین ره که می‌زنی
# HINT: حضور غم و درخواست مراقبت ساقی و مطرب
# --------------------------------------------------------------------------------
# poem_id=481 bayt_id=2
# BAYT: آخرالامر گل کوزه‌گران خواهی شد / حالیا فکر سبو کن که پر از باده کنی
# HINT: یادآوری فناپذیری و توصیه به بهره‌جویی از فرصت
# --------------------------------------------------------------------------------
# poem_id=486 bayt_id=6
# BAYT: خوش، وقت بوریا و گدایی و خواب امن / کاین عیش، نیست درخور اورنگ خسروی
# HINT: آرامش فقر و بی‌نیازی در برابر شکوه سلطنت
# --------------------------------------------------------------------------------
# poem_id=489 bayt_id=1
# BAYT: ای در رخ تو پیدا انوار پادشاهی / در فکرت تو پنهان صد حکمت الهی
# HINT: تجلی شکوه و حکمت در ظاهر و باطن
# --------------------------------------------------------------------------------
# poem_id=489 bayt_id=2
# BAYT: کلک تو بارک الله بر ملک و دین گشاده / صد چشمه آب حیوان از قطره‌ی سیاهی
# HINT: تجلیل از اثر قلم بر عالم و دین
# --------------------------------------------------------------------------------
# poem_id=489 bayt_id=9
# BAYT: ساقی بیار آبی از چشمه‌ی خرابات / تا خرقه‌ها بشوییم از عجب خانقاهی
# HINT: درخواست آب خرابات برای شستن خرقه از عجب
# --------------------------------------------------------------------------------
# poem_id=490 bayt_id=9
# BAYT: این حدیثم چه خوش آمد که سحرگه می‌گفت / بر در میکده‌ای، با دف و نی، ترسایی
# HINT: شنیدن سخن خوشایند در سحرگاه بر در میکده
# --------------------------------------------------------------------------------
# poem_id=492 bayt_id=9
# BAYT: مرا گر تو بگذاری ای نفس طامع / بسی پادشایی کنم در گدایی
# HINT: رهایی از قید نفس و عزت در فقر
# --------------------------------------------------------------------------------
# poem_id=493 bayt_id=8
# BAYT: ای درد توام درمان در بستر ناکامی / وی یاد توام مونس در گوشه‌ی تنهایی
# HINT: درد و یاد محبوب در ناکامی و تنهایی
# --------------------------------------------------------------------------------
# poem_id=494 bayt_id=7
# BAYT: بر رهگذرت بسته‌ام از دیده، دو صد جوی / تا بو که تو چون سرو خرامان به درآیی
# HINT: انتظار بر سر راه معشوق با اشک فراوان
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Affect label distribution
#
# We inspect the frequency of affect labels to ensure reasonable coverage
# and detect skew or collapse.

# %%
affects = [a for r in rows for a in r["affect"]]
Counter(affects)
# Out:
# Counter({'حسرت': 1483,
#          'شوق': 1251,
#          'امید': 752,
#          'اندوه': 751,
#          'بی\u200cقراری': 538,
#          'آرامش': 450,
#          'حیرت': 398,
#          'ناامیدی': 113})

# %% [markdown]
# ### Affect cardinality check
#
# Each bayt may have 0, 1, or 2 affect labels.

# %%
Counter(len(r["affect"]) for r in rows)
# Out:
# Counter({1: 2056, 2: 1840, 0: 296})

# %% [markdown]
# ### Random global inspection
#
# A random sample of bayts is inspected to verify overall annotation quality.

# %%
random.seed(42)

for r in random.sample(rows, 10):
    key = (r["poem_id"], r["bayt_id"])
    print(f"poem_id={r['poem_id']} bayt_id={r['bayt_id']}")
    print("BAYT:", raw_by_key[key])
    print("HINT:", r["bayt_hint"])
    print("AFFECT:", r["affect"])
    print("-" * 80)
# Out:
# poem_id=110 bayt_id=6
# BAYT: بس تجربه کردیم در این دیر مکافات / با دردکشان هر که درافتاد برافتاد
# HINT: آزمون دشواری‌ها و سرنوشت دردکشان
# AFFECT: ['اندوه']
# --------------------------------------------------------------------------------
# poem_id=24 bayt_id=3
# BAYT: می بده تا دهمت آگهی از سر قضا / که به روی که شدم عاشق و از بوی که مست
# HINT: درخواست می و بیان راز عاشقی
# AFFECT: ['شوق']
# --------------------------------------------------------------------------------
# poem_id=269 bayt_id=7
# BAYT: هوای مسکن مالوف و عهد یار قدیم / ز رهروان سفرکرده، عذرخواهت بس
# HINT: یاد خانه آشنا و عهد دوست قدیم
# AFFECT: ['حسرت']
# --------------------------------------------------------------------------------
# poem_id=241 bayt_id=4
# BAYT: چو در میان مراد آورید دست امید / ز عهد صحبت ما در میانه یاد آرید
# HINT: یادآوری عهد دوستی
# AFFECT: ['امید', 'حسرت']
# --------------------------------------------------------------------------------
# poem_id=219 bayt_id=4
# BAYT: شد از خروج ریاحین چو آسمان روشن- / زمین، به اختر میمون و طالع مسعود
# HINT: روشنایی آسمان و خوش‌طالع شدن زمین
# AFFECT: ['امید']
# --------------------------------------------------------------------------------
# poem_id=137 bayt_id=6
# BAYT: صبا گر چاره داری وقت، وقت است / که درد اشتیاقم قصد جان کرد
# HINT: درخواست یاری از باد صبا
# AFFECT: ['شوق', 'بی\u200cقراری']
# --------------------------------------------------------------------------------
# poem_id=100 bayt_id=5
# BAYT: حافظ گرت ز پند حکیمان ملالت است / کوته کنیم قصه، که عمرت دراز باد
# HINT: پیشنهاد کوتاهی سخن به سبب ملالت از پند
# AFFECT: []
# --------------------------------------------------------------------------------
# poem_id=85 bayt_id=4
# BAYT: عشوه دادند که بر ما گذری خواهی کرد / دیدی آخر که چنین عشوه خریدیم و برفت
# HINT: وعده و فریب معشوق
# AFFECT: ['حسرت', 'اندوه']
# --------------------------------------------------------------------------------
# poem_id=413 bayt_id=5
# BAYT: سلطان غم هر آن چه تواند بگو بکن / من برده‌ام به باده‌فروشان پناه از او
# HINT: پناه‌جویی از غم نزد باده‌فروشان
# AFFECT: ['اندوه', 'شوق']
# --------------------------------------------------------------------------------
# poem_id=31 bayt_id=6
# BAYT: من نخواهم کرد ترک لعل یار و جام می / زاهدان معذور داریدم که اینم مذهب است
# HINT: پافشاری بر شیوه عاشقانه
# AFFECT: ['شوق']
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Inspection of normalized bayt hints
#
# Bayt hints modified by rule-based normalization are inspected
# to ensure semantic content was preserved.

# %%
normalized = [
    r for r in rows
    if r.get("annotation_meta", {}).get("manual_norm") is True
]

len(normalized)
# Out:
# 186

# %%
random.seed(42)

for r in random.sample(normalized, 10):
    key = (r["poem_id"], r["bayt_id"])
    print(f"poem_id={r['poem_id']} bayt_id={r['bayt_id']}")
    print("BAYT:", raw_by_key[key])
    print("HINT:", r["bayt_hint"])
    print("-" * 80)
# Out:
# poem_id=473 bayt_id=1
# BAYT: وقت را غنیمت دان آن قدر که بتوانی / حاصل از حیات ای جان این دم است تا دانی
# HINT: زمان
# --------------------------------------------------------------------------------
# poem_id=121 bayt_id=6
# BAYT: چو بر روی زمین باشی، توانایی، غنیمت دان / که دوران، ناتوانی‌ها، بسی زیر زمین دارد
# HINT: فرصت زندگی
# --------------------------------------------------------------------------------
# poem_id=29 bayt_id=7
# BAYT: سبز است در و دشت بیا تا نگذاریم / دست از سر آبی که جهان جمله سراب است
# HINT: لذت‌های زودگذر طبیعت
# --------------------------------------------------------------------------------
# poem_id=250 bayt_id=9
# BAYT: حافظ اندیشه کن از نازکی خاطر یار / برو از درگهش این ناله و فریاد ببر
# HINT: رعایت حال یار
# --------------------------------------------------------------------------------
# poem_id=239 bayt_id=4
# BAYT: مکن ز غصه شکایت که در طریق طلب / به راحتی نرسید آن که زحمتی نکشید
# HINT: شکیبایی در مسیر تلاش
# --------------------------------------------------------------------------------
# poem_id=196 bayt_id=10
# BAYT: بگذر به کوی میکده تا زمره‌ی حضور / اوقات خود ز بهر تو صرف دعا کنند
# HINT: میکده و دعای جمع
# --------------------------------------------------------------------------------
# poem_id=151 bayt_id=7
# BAYT: چو حافظ در قناعت کوش و از دنیای دون بگذر / که یک جو منت دونان دو صد من زر نمی‌ارزد
# HINT: قناعت و بی‌اعتنایی به دنیا
# --------------------------------------------------------------------------------
# poem_id=115 bayt_id=5
# BAYT: بهار عمر خواه ای دل، وگرنه این چمن هر سال / چو نسرین صد گل آرد بار و چون بلبل هزار آرد
# HINT: فرصت زندگی
# --------------------------------------------------------------------------------
# poem_id=482 bayt_id=1
# BAYT: ای دل به کوی عشق گذاری نمی‌کنی / اسباب جمع داری و کاری نمی‌کنی
# HINT: حرکت عاشقانه
# --------------------------------------------------------------------------------
# poem_id=431 bayt_id=4
# BAYT: بده جام می و از جم مکن یاد / که می‌داند که جم کی بود و کی کی؟
# HINT: فراموشی گذشته و توجه به حال
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Affect-specific slice inspection
#
# We inspect bayts sharing the same affect label to verify semantic coherence.

# %%
subset = [r for r in rows if "حسرت" in r["affect"]]

random.seed(123)

for r in random.sample(subset, 8):
    key = (r["poem_id"], r["bayt_id"])
    print(f"poem_id={r['poem_id']} bayt_id={r['bayt_id']}")
    print("BAYT:", raw_by_key[key])
    print("HINT:", r["bayt_hint"])
    print("AFFECT:", r["affect"])
    print("-" * 80)
# Out:
# poem_id=30 bayt_id=2
# BAYT: تا عاشقان به بوی نسیمش دهند جان / بگشود نافه‌ای و در آرزو ببست
# HINT: بوی خوش نسیم و بسته شدن در آرزو
# AFFECT: ['حسرت']
# --------------------------------------------------------------------------------
# poem_id=179 bayt_id=7
# BAYT: توانگرا! دل درویش خود به دست آور / که مخزن زر و گنج درم نخواهد ماند
# HINT: جلب محبت نیازمند
# AFFECT: ['حسرت']
# --------------------------------------------------------------------------------
# poem_id=56 bayt_id=8
# BAYT: دور مجنون گذشت و نوبت ماست / هر کسی پنج روز، نوبت اوست
# HINT: پایان نوبت پیشینیان و آغاز نوبت جدید
# AFFECT: ['حسرت']
# --------------------------------------------------------------------------------
# poem_id=280 bayt_id=5
# BAYT: جمال کعبه مگر عذر رهروان خواهد / که جان زنده دلان سوخت در بیابانش
# HINT: رنج عاشقان در راه وصال
# AFFECT: ['حسرت', 'اندوه']
# --------------------------------------------------------------------------------
# poem_id=179 bayt_id=2
# BAYT: من ار چه در نظر یار خاک‌سار شدم / رقیب نیز چنین محترم نخواهد ماند
# HINT: مقایسه جایگاه عاشق و رقیب نزد معشوق
# AFFECT: ['حسرت']
# --------------------------------------------------------------------------------
# poem_id=70 bayt_id=3
# BAYT: بسته‌ی دام و قفس باد چو مرغ وحشی / طایر سدره اگر در طلبت طایر نیست
# HINT: آرزوی رهایی در بند محدودیت
# AFFECT: ['شوق', 'حسرت']
# --------------------------------------------------------------------------------
# poem_id=21 bayt_id=3
# BAYT: شمع اگر زان لب خندان به زبان، لافی زد / پیش عشاق تو شب‌ها به غرامت برخاست
# HINT: ادعای شمع در برابر زیبایی معشوق
# AFFECT: ['شوق', 'حسرت']
# --------------------------------------------------------------------------------
# poem_id=257 bayt_id=8
# BAYT: میل رفتن مکن ای دوست دمی با ما باش / بر لب جوی، طرب جوی و به کف ساغر گیر
# HINT: درخواست ماندن یار و جست‌وجوی شادی
# AFFECT: ['شوق', 'حسرت']
# --------------------------------------------------------------------------------
